# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/3bins/pretrained/init.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'decomposer.Decomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Vocab size = 138,444

# %%
# base_dir = Path('../../results/news/validation')
base_dir = Path('../../results/3bins recomp/')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='*/epoch1.pt', recomposer=True)

print(deno_space.keys())
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# Loading ../../results/3bins recomp/L1/epoch1.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'recomposer.Recomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Loading ../../results/3bins recomp/clamp L4/epoch1.pt
# Loading ../../results/3bins recomp/focus recomp/epoch1.pt
#
# dict_keys(['L1/epoch1.pt', 'clamp L4/epoch1.pt', 'focus recomp/epoch1.pt'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['clamp L4/epoch1.pt']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
    GD(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ====================================================================================================
#              Dataset             Rho       Reference      Delta >.02
# ====================================================================================================
#     EN-MTurk-771.txt         55.00%         52.84%           2.16%
#   EN-RW-STANFORD.txt         47.31%         45.33%               𝜀
#    EN-SIMLEX-999.txt         33.30%         32.92%               𝜀
#     EN-MTurk-287.txt         57.64%         59.11%               𝜀
#        EN-YP-130.txt         53.55%         50.72%           2.82%
#    EN-WS-353-SIM.txt         72.96%         68.51%           4.45%
#     EN-MEN-TR-3k.txt         62.62%         52.49%          10.14%
#    EN-WS-353-REL.txt         56.61%         44.70%          11.91%
#      EN-VERB-143.txt         21.54%         29.87%          -8.33%
#    EN-WS-353-ALL.txt         63.89%         58.16%           5.73%
#  EN-SimVerb-3500.txt         24.10%         26.25%          -2.15%
# Mean Delta = 2.5106%

# %%
GD('aca')

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# gun_violence	1, 0, 0,
# Pretrained:
# 0.7120	mass_shootings
# 0.6513	gun-related
# 0.6494	gun_deaths
# 0.6420	developed_peers
# 0.6395	school_shootings
# 0.6338	stricter_gun
# 0.6317	gun_ownership
# 0.6275	control_laws
# 0.6242	shootings
# 0.6238	america_gun
#
# Our model:
# 0.5743	mass_shootings
# 0.5175	gun_ownership
# 0.5151	shootings
# 0.5061	gun_laws
# 0.5019	gun_deaths
# 0.4918	gun-related
# 0.4915	mass_shooting
# 0.4801	guns
# 0.4753	stricter_gun
# 0.4719	gun_control
#
# single_payer	1, 0, 0,
# Pretrained:
# 0.7089	universal_coverage
# 0.6919	universal_healthcare
# 0.6774	universal_health
# 0.6704	free_college
# 0.6649	socialized_medicine
# 0.6543	public_option
# 0.6377	sanders_plan
# 0.6228	health_care
# 0.6222	cost_control
# 0.6202	comprehensive_health
#
# Our model:
# 0.5625	universal_health
# 0.5280	universal_healthcare
# 0.4984	universal_coverage
# 0.4745	free_college
# 0.4656	health_care
# 0.4625	public_option
# 0.4448	socialized_medicine
# 0.4377	care_system
# 0.4268	national_health
# 0.4238	healthcare_system
#
# medicaid_expansion	0, 0, 0,
# Pretrained:
# 0.7897	obamacare_medicaid
# 0.7886	expand_medicaid
# 0.7818	expanding_medicaid
# 0.7655	expanded_medicaid
# 0.7500	medicaid_program
# 0.7497	medicaid
# 0.7004	health_law
# 0.6967	state_medicaid
# 0.6909	insurance_subsidies
# 0.6891	federal_health
#
# Our model:
# 0.6539	expand_medicaid
# 0.6170	obamacare_medicaid
# 0.6110	medicaid
# 0.5948	expanding_medicaid
# 0.5941	expanded_medicaid
# 0.5622	medicaid_program
# 0.5488	health_law
# 0.5399	state_medicaid
# 0.5291	federal_health
# 0.4882	obamacare_insurance
#
# birth_control	1, 0, 0,
# Pretrained:
# 0.8290	contraception
# 0.8005	contraceptives
# 0.7594	contraceptive
# 0.6743	abortion
# 0.6636	iuds
# 0.6611	emergency_contraception
# 0.6598	abortifacients
# 0.6374	long_acting
# 0.6347	reproductive_health
# 0.6334	contraceptive_coverage
#
# Our model:
# 0.7401	contraception
# 0.6648	contraceptives
# 0.6308	contraceptive
# 0.5368	abortion
# 0.4878	reproductive_health
# 0.4864	abortions
# 0.4758	pills
# 0.4492	iuds
# 0.4466	pill
# 0.4438	insurance_coverage
#
# tax_returns	1, 0, 0,
# Pretrained:
# 0.6483	tax_records
# 0.6323	college_records
# 0.6304	romney_wo
# 0.6284	romney_tax
# 0.6185	multiple_years
# 0.6005	hiding_something
# 0.6004	tax_documents
# 0.5936	financial_disclosures
# 0.5736	trump_taxes
# 0.5711	financial_disclosure
#
# Our model:
# 0.4632	release
# 0.4166	romney_tax
# 0.4140	medical_records
# 0.4026	tax_records
# 0.3687	returns
# 0.3661	releasing
# 0.3633	disclose
# 0.3592	hiding_something
# 0.3571	financial_disclosure
# 0.3528	paying_taxes
#
# global_warming	1, 0, 0,
# Pretrained:
# 0.8255	climate_change
# 0.7334	human_caused
# 0.6899	warming
# 0.6755	anthropogenic_global
# 0.6744	human_activity
# 0.6732	climate_crisis
# 0.6692	human_induced
# 0.6624	greenhouse_effect
# 0.6620	skeptic_guide
# 0.6575	climate_scientists
#
# Our model:
# 0.7784	climate_change
# 0.6145	warming
# 0.5565	climate
# 0.5267	human_caused
# 0.5235	climate_scientists
# 0.5116	global_climate
# 0.5084	human_activity
# 0.4789	deniers
# 0.4668	greenhouse_gases
# 0.4538	james_hansen
#
# climate_change	0, 0, 0,
# Pretrained:
# 0.8255	global_warming
# 0.7080	human_caused
# 0.6769	global_climate
# 0.6734	human_induced
# 0.6595	called_climate
# 0.6582	human_activity
# 0.6564	intergovernmental_panel
# 0.6532	world_climate
# 0.6522	anthropogenic_global
# 0.6375	warming_planet
#
# Our model:
# 0.7784	global_warming
# 0.5699	climate
# 0.5280	global_climate
# 0.5090	human_caused
# 0.4971	warming
# 0.4939	intergovernmental_panel
# 0.4828	human_activity
# 0.4805	deniers
# 0.4773	climate_scientists
# 0.4719	climate_science
#
# clean_energy	0, 0, 0,
# Pretrained:
# 0.6108	renewable_energy
# 0.6012	green_energy
# 0.5973	energy_efficiency
# 0.5904	solar_energy
# 0.5880	clean_renewable
# 0.5860	renewables
# 0.5665	low_carbon
# 0.5652	lower_carbon
# 0.5648	wind_solar
# 0.5630	new_energy
#
# Our model:
# 0.5191	renewable_energy
# 0.4753	energy_efficiency
# 0.4368	renewables
# 0.4227	green_energy
# 0.4122	solar
# 0.4088	solar_energy
# 0.4053	new_energy
# 0.3975	alternative_energy
# 0.3951	solar_power
# 0.3931	wind_power
#
# undocumented_immigrants	0, 1, 0,
# Pretrained:
# 0.7615	illegal_immigrants
# 0.7573	million_undocumented
# 0.7503	unauthorized_immigrants
# 0.7347	young_undocumented
# 0.7150	illegal_aliens
# 0.7006	immigrants
# 0.6988	million_unauthorized
# 0.6975	immigrants_living
# 0.6945	young_illegal
# 0.6933	called_dreamers
#
# Our model:
# 0.6512	illegal_immigrants
# 0.5985	immigrants
# 0.5851	million_undocumented
# 0.5820	illegal_aliens
# 0.5768	unauthorized_immigrants
# 0.5445	undocumented
# 0.5333	country_illegally
# 0.5077	million_illegal
# 0.5031	work_permits
# 0.5027	state_tuition
#
# counterterrorism_wars	0, 0, 1,
# Pretrained:
# 0.9326	africa_nigeria
# 0.9240	conflict_heads
# 0.9058	counterterrorism_heads
# 0.9035	conflict_niger
# 0.9016	religion_terrorism
# 0.9012	voting_terrorism
# 0.9010	counterterrorism_corruption
# 0.8993	counterterrorism_nigeria
# 0.8960	africa_terrorism
# 0.8890	conflict_defense
#
# Our model:
# 0.8694	africa_nigeria
# 0.8389	conflict_heads
# 0.8056	counterterrorism_nigeria
# 0.8045	africa_terrorism
# 0.7996	counterterrorism_heads
# 0.7852	voting_terrorism
# 0.7836	religion_terrorism
# 0.7821	conflict_niger
# 0.7813	counterterrorism_corruption
# 0.7730	nigeria_terrorism
#
# us_debt	0, 0, 0,
# Pretrained:
# 0.7474	term_assets
# 0.7446	us_equities
# 0.7415	agency_debt
# 0.7407	recorded_purchases
# 0.7401	foreign_securities
# 0.7368	russian_holdings
# 0.7367	treasury_portfolio
# 0.7307	us_treasuries
# 0.7294	official_investors
# 0.7287	private_purchases
#
# Our model:
# 0.5668	us_long
# 0.5563	private_purchases
# 0.5491	us_bonds
# 0.5474	agency_bonds
# 0.5441	us_treasuries
# 0.5437	us_equities
# 0.5309	foreign_securities
# 0.5267	term_debt
# 0.5249	foreign_purchases
# 0.5192	foreign_demand
#
# monetary_policy	0, 0, 0,
# Pretrained:
# 0.6341	zero_bound
# 0.6049	taylor_rule
# 0.5671	markets_united
# 0.5642	states_budget
# 0.5604	forward_guidance
# 0.5595	deficits_united
# 0.5594	states_monetary
# 0.5584	japan_boj
# 0.5574	dual_mandate
# 0.5518	yellen
#
# Our model:
# 0.4503	federal_reserve
# 0.4337	zero_bound
# 0.4207	yellen
# 0.4018	bernanke
# 0.3909	fed
# 0.3902	financial_markets
# 0.3857	forward_guidance
# 0.3721	tapering
# 0.3578	taylor_rule
# 0.3532	european_central
#
# financial_markets	0, 0, 0,
# Pretrained:
# 0.5817	markets_united
# 0.5796	development_monetary
# 0.5792	policy_brazil
# 0.5782	china_economics
# 0.5746	europe_international
# 0.5719	states_monetary
# 0.5709	fuels_financial
# 0.5707	eurasia_financial
# 0.5693	states_budget
# 0.5686	europe_economics
#
# Our model:
# 0.4158	markets
# 0.3902	monetary_policy
# 0.3733	china_economics
# 0.3731	deficits_trade
# 0.3702	budget_debt
# 0.3608	economic_crises
# 0.3516	capital_flows
# 0.3377	eurasia_capital
# 0.3370	federal_reserve
# 0.3340	global_capital
#
# violence_racism	0, 0, 1,
# Pretrained:
# 0.9338	vulgarity_profanity
# 0.9162	comments_containing
# 0.9054	advertising_vulgarity
# 0.8926	contain_spam
# 0.8911	discourteous_behavior
# 0.8760	remove_comments
# 0.7433	au_leaders
# 0.7141	ensued—there
# 0.6907	international_scandal
# 0.6819	edit
#
# Our model:
# 0.8601	vulgarity_profanity
# 0.8449	comments_containing
# 0.8183	advertising_vulgarity
# 0.7973	contain_spam
# 0.7796	discourteous_behavior
# 0.7714	remove_comments
# 0.6802	personal_abusive
# 0.5693	edit
# 0.5384	au_leaders
# 0.4964	ensued—there
#
# permanently_banned	0, 0, 1,
# Pretrained:
# 0.9687	site_administrators
# 0.9546	repeat_offenders
# 0.9524	sole_discretion
# 0.8788	without_warning
# 0.7501	week_technology
# 0.7466	quick_round
# 0.6451	east_strategic
# 0.6342	alive_send
# 0.6326	fact_vietnam
# 0.6324	expressly_prohibited
#
# Our model:
# 0.9455	site_administrators
# 0.9329	repeat_offenders
# 0.9171	sole_discretion
# 0.8345	without_warning
# 0.6077	week_technology
# 0.5944	quick_round
# 0.5369	blocked
# 0.5199	members_may
# 0.4898	tribune_donors
# 0.4794	corporate_sponsor
#
# anti-semitism	0, 0, 0,
# Pretrained:
# 0.6710	anti-zionism
# 0.6244	anti-israelism
# 0.6229	anti-jewish
# 0.6192	islamophobia
# 0.6148	au_leaders
# 0.6128	racism
# 0.5832	advertising_vulgarity
# 0.5795	racism_sexism
# 0.5759	jews_everywhere
# 0.5749	delegitimization
#
# Our model:
# 0.6789	personal_abusive
# 0.4850	advertising_vulgarity
# 0.4787	contain_spam
# 0.4491	threats
# 0.4482	edit
# 0.4445	remove_comments
# 0.4318	violence_racism
# 0.4245	au_leaders
# 0.4048	racism
# 0.3789	islamophobia
#
# neocons	0, 0, 0,
# Pretrained:
# 0.7768	neoconservatives
# 0.7679	liberal_interventionist
# 0.7555	liberal_interventionists
# 0.6919	warmongers
# 0.6908	official_washington
# 0.6907	neoconservative
# 0.6850	war_hawks
# 0.6562	interventionists
# 0.6561	pers
# 0.6554	war_party
#
# Our model:
# 0.5885	neoconservatives
# 0.4995	liberal_interventionist
# 0.4920	neoconservative
# 0.4874	liberal_interventionists
# 0.4347	warmongers
# 0.4275	official_washington
# 0.4228	robert_kagan
# 0.3892	war_hawks
# 0.3857	zionists
# 0.3834	richard_perle
#
# veterans	0, 0, 0,
# Pretrained:
# 0.7809	vets
# 0.7120	combat_veterans
# 0.7079	disabled_veterans
# 0.7063	helping_veterans
# 0.7023	veterans_affairs
# 0.6949	military_families
# 0.6944	local_veterans
# 0.6942	disabled_american
# 0.6921	many_veterans
# 0.6910	million_veterans
#
# Our model:
# 0.6673	vets
# 0.6262	veterans_affairs
# 0.5948	va
# 0.4803	military_veterans
# 0.4776	service_members
# 0.4697	ptsd
# 0.4671	many_veterans
# 0.4669	military_families
# 0.4635	veterans_administration
# 0.4549	vietnam_veterans
#
# professors	0, 0, 0,
# Pretrained:
# 0.6860	faculty
# 0.6798	students
# 0.6631	university_professors
# 0.6569	faculty_members
# 0.6533	college_professors
# 0.6505	deans
# 0.6449	profs
# 0.6181	uchicago
# 0.6163	law_schools
# 0.6162	law_professors
#
# Our model:
# 0.5602	faculty
# 0.5155	students
# 0.4712	campus
# 0.4566	faculty_members
# 0.4531	university_professors
# 0.4524	campuses
# 0.4243	colleges
# 0.4209	undergraduates
# 0.4200	universities
# 0.4142	university
#
# jihadists	0, 0, 0,
# Pretrained:
# 0.6833	jihadi_groups
# 0.6781	muslim_extremists
# 0.6714	takfiri
# 0.6714	isis_al
# 0.6700	islamic_extremists
# 0.6684	jihadi
# 0.6667	sunni_extremists
# 0.6593	islamic_terrorists
# 0.6555	terrorists
# 0.6553	islamist_fighters
#
# Our model:
# 0.4819	jihadi
# 0.4784	isis
# 0.4683	terrorists
# 0.4391	al_qaeda
# 0.4253	wahhabi
# 0.4196	foreign_fighters
# 0.4157	islamic_extremists
# 0.4140	islamic_state
# 0.4066	terrorist_groups
# 0.4033	terror_groups
#
# irs	0, 0, 0,
# Pretrained:
# 0.7581	internal_revenue
# 0.7022	lois_lerner
# 0.6699	irs_targeting
# 0.6511	irs_official
# 0.6507	i.r.s.
# 0.6430	obama_irs
# 0.6290	irs_agents
# 0.6263	tax_exempt
# 0.6247	irs_officials
# 0.6243	extra_scrutiny
#
# Our model:
# 0.6513	internal_revenue
# 0.5231	tax_exempt
# 0.5074	lois_lerner
# 0.4825	conservative_groups
# 0.4497	irs_targeting
# 0.4329	lerner
# 0.4140	extra_scrutiny
# 0.3992	i.r.s.
# 0.3858	irs_officials
# 0.3713	irs_official
#
# social_justice	0, 0, 0,
# Pretrained:
# 0.6287	economic_justice
# 0.5979	anti-racism
# 0.5965	intersectional
# 0.5829	sjw
# 0.5814	intersectionality
# 0.5792	philadelphia_based
# 0.5639	environmental_stewardship
# 0.5629	men_rights
# 0.5625	intellectual_diversity
# 0.5623	activists_like
#
# Our model:
# 0.3627	economic_justice
# 0.3351	activists
# 0.3344	environmental_justice
# 0.3341	environmental
# 0.3098	feminists
# 0.3046	sjw
# 0.2997	climate_justice
# 0.2989	anti-racism
# 0.2935	warriors
# 0.2889	justice
#
# political_correctness	0, 0, 0,
# Pretrained:
# 0.6404	cultural_marxism
# 0.6327	yale_porn
# 0.6207	book_sex
# 0.6195	identity_politics
# 0.6187	toxic_masculinity
# 0.6107	politically_correct
# 0.6071	sjws
# 0.6064	gay_agenda
# 0.6055	nathan_harden
# 0.6051	destroying_america
#
# Our model:
# 0.4224	politically_correct
# 0.3986	identity_politics
# 0.3938	good_education
# 0.3777	yale_porn
# 0.3753	nathan_harden
# 0.3642	gone_bad
# 0.3592	book_sex
# 0.3152	correctness
# 0.3136	microaggressions
# 0.3050	american_exceptionalism
#
# mainstream_media	0, 0, 0,
# Pretrained:
# 0.7181	msm
# 0.7103	mainstream_press
# 0.6923	corporate_media
# 0.6734	liberal_media
# 0.6671	called_mainstream
# 0.6661	leftist_media
# 0.6617	establishment_press
# 0.6597	main_stream
# 0.6586	us_media
# 0.6574	establishment_media
#
# Our model:
# 0.5668	msm
# 0.4875	media
# 0.4792	corporate_media
# 0.4785	mainstream_press
# 0.4750	outlets
# 0.4672	news_media
# 0.4635	liberal_media
# 0.4381	us_media
# 0.4332	main_stream
# 0.4143	western_media
#
# hillary	0, 0, 0,
# Pretrained:
# 0.8379	hillary_clinton
# 0.8080	clinton
# 0.6890	clintons
# 0.6791	like_hillary
# 0.6725	said_hillary
# 0.6712	crooked_hillary
# 0.6694	see_clinton
# 0.6600	hillary_campaign
# 0.6592	nominee_hillary
# 0.6586	see_hillary
#
# Our model:
# 0.7231	hillary_clinton
# 0.6960	clinton
# 0.5205	clinton_campaign
# 0.5128	clintons
# 0.5099	bernie
# 0.4763	nominee_hillary
# 0.4699	sanders
# 0.4640	bernie_sanders
# 0.4636	hillary_rodham
# 0.4578	mrs._clinton
#
# tax_cuts	0, 0, 0,
# Pretrained:
# 0.7336	bush_tax
# 0.7202	cutting_taxes
# 0.6933	wealthiest_americans
# 0.6722	unfunded_tax
# 0.6653	trillion_tax
# 0.6622	cut_taxes
# 0.6614	cuts_expire
# 0.6607	wealthy_tax
# 0.6539	large_tax
# 0.6505	unfunded_wars
#
# Our model:
# 0.6042	bush_tax
# 0.5579	cutting_taxes
# 0.5325	cuts
# 0.5319	wealthiest_americans
# 0.4859	tax_increases
# 0.4798	bush_era
# 0.4767	cut_taxes
# 0.4678	unfunded_tax
# 0.4612	rich
# 0.4541	large_tax

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# estate_tax	0, 0, 0,
# Pretrained:
# 0.8058	death_tax
# 0.7939	inheritance_tax
# 0.7891	alternative_minimum
# 0.7830	surtax
# 0.7819	richest_americans
# 0.7713	top_tax
# 0.7479	individual_tax
# 0.7476	trillion_tax
# 0.7456	marriage_penalty
# 0.7389	top_rate
#
# Our model:
# 0.6371	death_tax
# 0.6367	alternative_minimum
# 0.5963	individual_tax
# 0.5914	surtax
# 0.5893	richest_americans
# 0.5777	top_tax
# 0.5696	inheritance_tax
# 0.5662	top_rate
# 0.5582	child_tax
# 0.5522	marginal_tax
#
# death_tax	0, 0, 0,
# Pretrained:
# 0.8740	inheritance_tax
# 0.8266	surtax
# 0.8179	estate_taxes
# 0.8133	wealthy_tax
# 0.8133	obamacare_taxes
# 0.8108	alternative_minimum
# 0.8090	cuts_expire
# 0.8088	personal_exemptions
# 0.8077	raises_taxes
# 0.8068	marriage_penalty
#
# Our model:
# 0.7210	inheritance_tax
# 0.7115	estate_taxes
# 0.6892	surtax
# 0.6730	obamacare_taxes
# 0.6696	cuts_expire
# 0.6608	existing_tax
# 0.6555	itemized_deductions
# 0.6522	marriage_penalty
# 0.6507	wealthy_tax
# 0.6500	regressive_tax

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# undocumented_workers	0, 0, 0,
# Pretrained:
# 0.7386	unauthorized_workers
# 0.7354	work_visas
# 0.7099	hire_illegal
# 0.7078	million_undocumented
# 0.7017	temporary_work
# 0.7002	young_undocumented
# 0.6967	million_unauthorized
# 0.6966	work_authorization
# 0.6951	young_illegal
# 0.6937	called_dreamers
#
# Our model:
# 0.5707	million_undocumented
# 0.5543	unauthorized_workers
# 0.5406	million_illegal
# 0.5269	work_visas
# 0.5266	immigrants_would
# 0.5139	immigrant_families
# 0.5137	million_immigrants
# 0.5022	undocumented_immigrant
# 0.5017	million_unauthorized
# 0.4992	legal_immigrants
#
# illegal_aliens	0, 0, 0,
# Pretrained:
# 0.7453	illegal_immigrants
# 0.7422	illegals
# 0.7150	undocumented_immigrants
# 0.7089	criminal_illegal
# 0.6989	criminal_aliens
# 0.6969	illegal_immigrant
# 0.6916	million_illegal
# 0.6883	young_illegal
# 0.6855	unauthorized_immigrants
# 0.6716	million_immigrants
#
# Our model:
# 0.6154	illegals
# 0.5970	illegal_immigrants
# 0.5820	undocumented_immigrants
# 0.5400	illegal_immigrant
# 0.5277	immigrants
# 0.5181	unauthorized_immigrants
# 0.5114	million_illegal
# 0.5059	undocumented
# 0.5005	criminal_aliens
# 0.4999	criminal_illegal
#
# chain_migration	0, 0, 0,
# Pretrained:
# 0.7758	family_based
# 0.7758	million_illegals
# 0.7676	young_illegal
# 0.7648	immigration_advocates
# 0.7614	immigration_reforms
# 0.7574	immigration_plan
# 0.7560	iirira
# 0.7544	called_dreamers
# 0.7540	raise_act
# 0.7516	young_undocumented
#
# Our model:
# 0.6637	family_based
# 0.6329	iirira
# 0.6206	immigration_reforms
# 0.6119	raise_act
# 0.6081	young_undocumented
# 0.6070	immigration_advocates
# 0.6017	million_unauthorized
# 0.5988	young_illegal
# 0.5867	undocumented_children
# 0.5852	million_illegals

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare	0, 0, 0,
# Pretrained:
# 0.8302	aca
# 0.8285	affordable_care
# 0.7863	health_law
# 0.7632	act_aca
# 0.7479	obamacare_insurance
# 0.7416	obamacare_would
# 0.7394	patient_protection
# 0.7364	republican_plan
# 0.7360	healthcare_law
# 0.7340	care_law
#
# Our model:
# 0.7311	affordable_care
# 0.7148	aca
# 0.6139	health_law
# 0.5942	health_insurance
# 0.5689	individual_mandate
# 0.5337	buy_insurance
# 0.5329	health_care
# 0.5301	care_law
# 0.5239	obamacare_would
# 0.5212	republican_plan
#
# aca	1, 0, 0,
# Pretrained:
# 0.8302	obamacare
# 0.8112	affordable_care
# 0.7640	individual_mandate
# 0.7463	health_law
# 0.7154	act_aca
# 0.7030	patient_protection
# 0.6975	obamacare_insurance
# 0.6948	healthcare_law
# 0.6799	buy_health
# 0.6786	obamacare_would
#
# Our model:
# 0.7333	affordable_care
# 0.7148	obamacare
# 0.6786	individual_mandate
# 0.6139	health_law
# 0.5539	buy_health
# 0.5416	act_aca
# 0.5413	patient_protection
# 0.5307	health_insurance
# 0.5242	marketplaces
# 0.5177	care_law
#
# public_option	0, 1, 0,
# Pretrained:
# 0.7152	medicare_buy
# 0.6861	public_plan
# 0.6798	health_reform
# 0.6649	healthcare_reform
# 0.6599	graham_cassidy
# 0.6543	single_payer
# 0.6473	care_reform
# 0.6458	universal_coverage
# 0.6452	comprehensive_health
# 0.6428	healthcare_bill
#
# Our model:
# 0.4883	healthcare_reform
# 0.4837	government_run
# 0.4760	health_reform
# 0.4625	single_payer
# 0.4625	medicare_buy
# 0.4577	public_plan
# 0.4518	care_reform
# 0.4495	universal_coverage
# 0.4438	private_health
# 0.4412	health_care
#
# single_payer	1, 0, 0,
# Pretrained:
# 0.7089	universal_coverage
# 0.6919	universal_healthcare
# 0.6774	universal_health
# 0.6704	free_college
# 0.6649	socialized_medicine
# 0.6543	public_option
# 0.6377	sanders_plan
# 0.6228	health_care
# 0.6222	cost_control
# 0.6202	comprehensive_health
#
# Our model:
# 0.5625	universal_health
# 0.5280	universal_healthcare
# 0.4984	universal_coverage
# 0.4745	free_college
# 0.4656	health_care
# 0.4625	public_option
# 0.4448	socialized_medicine
# 0.4377	care_system
# 0.4268	national_health
# 0.4238	healthcare_system
#
# socialized_medicine	0, 0, 0,
# Pretrained:
# 0.7672	universal_healthcare
# 0.7619	like_obamacare
# 0.7597	socialistic
# 0.7479	life_counseling
# 0.7462	need_health
# 0.7448	healthcare_plan
# 0.7419	government_takeover
# 0.7390	expanding_coverage
# 0.7388	end_medicare
# 0.7350	universal_coverage
#
# Our model:
# 0.5856	universal_healthcare
# 0.5778	universal_coverage
# 0.5522	massachusetts_health
# 0.5477	insurance_system
# 0.5317	like_obamacare
# 0.5310	government_takeover
# 0.5310	socialistic
# 0.5297	healthcare_plan
# 0.5246	pre-obamacare
# 0.5240	need_health

# %%
cf('leftists')
cf('antifa')
# Out:
# leftists	0, 0, 0,
# Pretrained:
# 0.6805	called_liberals
# 0.6750	liberals
# 0.6546	america_hating
# 0.6530	sjws
# 0.6524	liberals_progressives
# 0.6519	left_wingers
# 0.6471	hate_mongers
# 0.6435	marxists
# 0.6434	radical_leftists
# 0.6414	upper_caste
#
# Our model:
# 0.4991	liberals
# 0.4579	socialists
# 0.4365	anarchists
# 0.4063	marxists
# 0.4045	libertarians
# 0.3875	conservatives
# 0.3787	progressives
# 0.3701	liberals_progressives
# 0.3648	far_left
# 0.3601	left_libertarians
#
# antifa	0, 0, 0,
# Pretrained:
# 0.7640	anti-fascist
# 0.7229	alt_left
# 0.7210	deray_mckesson
# 0.7154	blacklives_matter
# 0.7036	anti-fascists
# 0.7026	matter_protesters
# 0.6984	anti-trump_protesters
# 0.6881	black_bloc
# 0.6795	white_supremacists
# 0.6775	jason_kessler
#
# Our model:
# 0.5570	anti-fascist
# 0.5140	alt_left
# 0.5042	blacklives_matter
# 0.4968	deray_mckesson
# 0.4780	anti-fascists
# 0.4616	bamn
# 0.4616	white_supremacists
# 0.4560	black_bloc
# 0.4540	agitators
# 0.4539	matter_protesters

# %%
cf('guns')
# Out:
# guns	0, 0, 0,
# Pretrained:
# 0.7178	firearms
# 0.6305	gun_enthusiasts
# 0.6286	semi-automatic_weapons
# 0.6231	ammo
# 0.6207	handguns
# 0.6139	gun_laws
# 0.6128	buy_guns
# 0.6080	assault_rifles
# 0.6066	firearm
# 0.6060	semiautomatic_weapons
#
# Our model:
# 0.6705	firearms
# 0.5196	firearm
# 0.5026	gun_laws
# 0.4926	gun_owners
# 0.4859	ammo
# 0.4818	assault_weapons
# 0.4801	gun_violence
# 0.4760	rifles
# 0.4619	gun_ownership
# 0.4595	handguns

# %%
cf('trade')
# Out:
# trade	0, 0, 0,
# Pretrained:
# 0.5864	education_trade
# 0.5812	infrastructure_corporate
# 0.5559	actual_trade
# 0.5520	yen_carry
# 0.5515	trade_could
# 0.5504	investment_agreements
# 0.5465	corporate_regulation
# 0.5437	investment_flows
# 0.5435	u.s._goods
# 0.5382	corporate_governance
#
# Our model:
# 0.3897	investment
# 0.3667	markets
# 0.3588	china
# 0.3438	cap
# 0.3433	corporate_governance
# 0.3424	international_trade
# 0.3254	goods
# 0.3232	investment_agreements
# 0.3218	economic_ties
# 0.3174	trade_barriers

# %%
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
# Out:
# crooked_hillary	0, 0, 0,
# Pretrained:
# 0.7717	lyin
# 0.7677	lyin_ted
# 0.7644	lying_media
# 0.7625	nasty_woman
# 0.7605	little_marco
# 0.7530	candidate_ever
# 0.7529	attack_hillary
# 0.7513	attacking_hillary
# 0.7499	fucking_moron
# 0.7467	el_trumpo
#
# Our model:
# 0.5599	lyin_ted
# 0.5561	attacking_hillary
# 0.5530	nominee_hillary
# 0.5418	lyin
# 0.5322	candidate_ever
# 0.5292	little_marco
# 0.5134	democrat_hillary
# 0.4997	nasty_woman
# 0.4986	attack_hillary
# 0.4979	like_hillary
#
# lyin_ted	0, 1, 0,
# Pretrained:
# 0.8914	little_marco
# 0.8196	lyin
# 0.8062	small_hands
# 0.7978	ted_cruz.
# 0.7936	trump_calling
# 0.7881	real_donald
# 0.7807	cruz_wife
# 0.7804	snit
# 0.7803	still_trump
# 0.7776	typical_politician
#
# Our model:
# 0.7481	little_marco
# 0.6266	lyin
# 0.6218	trump_calling
# 0.5885	still_trump
# 0.5838	cruz_wife
# 0.5820	called_donald
# 0.5809	trump_wife
# 0.5801	heidi_cruz
# 0.5723	trump_replied
# 0.5690	clear_trump
#
# little_marco	0, 0, 0,
# Pretrained:
# 0.8914	lyin_ted
# 0.8575	lyin
# 0.8505	ted_cruz.
# 0.8434	even_donald
# 0.8349	real_donald
# 0.8236	birther_issue
# 0.8231	trump_calling
# 0.8220	like_jeb
# 0.8177	skidmore_flickr
# 0.8152	paladino
#
# Our model:
# 0.7481	lyin_ted
# 0.6722	vulgarian
# 0.6691	lyin
# 0.6689	called_donald
# 0.6630	even_donald
# 0.6619	trump_calling
# 0.6606	skidmore_flickr
# 0.6585	senate_colleague
# 0.6554	birther_issue
# 0.6459	like_jeb

# %%
cf('lgbt')
# Out:
# lgbt	0, 0, 0,
# Pretrained:
# 0.7207	gay_lesbian
# 0.6757	bisexual
# 0.6623	transgender_community
# 0.6552	lgbt_movement
# 0.6512	lgbt_community
# 0.6449	lesbian_rights
# 0.6414	lesbian_gay
# 0.6403	transgender
# 0.6371	transgender_issues
# 0.6366	bisexual_transgender
#
# Our model:
# 0.5122	gay_lesbian
# 0.4891	bisexual
# 0.4855	transgender
# 0.4829	gay
# 0.4712	lesbian
# 0.4516	sexual_orientation
# 0.4364	lgbt_community
# 0.4262	lesbian_gay
# 0.4063	gender_identity
# 0.4032	gay_rights
