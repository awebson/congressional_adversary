# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/search/Dd5.7 Dg-0.1 Cd-0.0 Cg0.9 R13.8 MAL8.3/epoch1.pt
# Vocab size = 138,443

# %%
# base_dir = Path('../../results/news/validation')
base_dir = Path('../../results/search/Dd5.7 Dg-0.1 Cd-0.0 Cg0.9 R13.8 MAL8.3/')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='epoch5.pt', recomposer=True)

print(deno_space.keys())
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# Loading ../../results/search/Dd5.7 Dg-0.1 Cd-0.0 Cg0.9 R13.8 MAL8.3/epoch5.pt
#
# dict_keys(['Dd5.7 Dg-0.1 Cd-0.0 Cg0.9 R13.8 MAL8.3/epoch5.pt'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['Dd5.7 Dg-0.1 Cd-0.0 Cg0.9 R13.8 MAL8.3/epoch5.pt']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
#     GD(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ====================================================================================================
#              Dataset             Rho       Reference      Delta >.02
# ====================================================================================================
#     EN-MTurk-771.txt         37.82%         49.62%         -11.80%
#   EN-RW-STANFORD.txt         24.33%         44.62%         -20.29%
#    EN-SIMLEX-999.txt         22.53%         30.70%          -8.18%
#     EN-MTurk-287.txt         52.24%         56.33%          -4.09%
#        EN-YP-130.txt         40.02%         41.14%               𝜀
#    EN-WS-353-SIM.txt         51.41%         63.87%         -12.46%
#     EN-MEN-TR-3k.txt         43.19%         47.35%          -4.16%
#    EN-WS-353-REL.txt         33.37%         41.71%          -8.34%
#      EN-VERB-143.txt         21.89%         29.87%          -7.99%
#    EN-WS-353-ALL.txt         39.91%         54.88%         -14.97%
#  EN-SimVerb-3500.txt         13.29%         25.62%         -12.33%
# Mean Delta = -9.6111%

# %%
GD('aca')

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# Pretrained:
# 0.7665	mass_shootings
# 0.6997	gun_deaths
# 0.6910	school_shootings
# 0.6739	gun_control
# 0.6735	gun-related
# 0.6655	developed_peers
# 0.6653	america_gun
# 0.6652	mass_shooting
# 0.6619	shootings
# 0.6607	gun_laws
#
# Our model:
# 0.6421	mass_shootings
# 0.5776	gun_control
# 0.5702	shootings
# 0.5657	gun_laws
# 0.5503	mass_shooting
# 0.5417	guns
# 0.5216	gun_ownership
# 0.4879	newtown
# 0.4837	homicides
# 0.4810	sandy_hook
#
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.6350	universal_health
# 0.5999	public_option
# 0.5687	government_run
# 0.5427	national_health
# 0.5081	health_care
# 0.4879	care_system
# 0.4803	universal_healthcare
# 0.4772	private_health
# 0.4767	private_insurance
# 0.4751	healthcare_system
#
# Pretrained:
# 0.8240	obamacare_medicaid
# 0.8239	expanding_medicaid
# 0.8146	expand_medicaid
# 0.8130	expanded_medicaid
# 0.8066	medicaid_program
# 0.7914	medicaid
# 0.7896	health_law
# 0.7493	federal_health
# 0.7473	block_grant
# 0.7464	kynect
#
# Our model:
# 0.6936	expand_medicaid
# 0.6757	medicaid
# 0.6671	expanded_medicaid
# 0.6410	medicaid_program
# 0.6298	federal_health
# 0.6131	health_law
# 0.5979	uninsured
# 0.5966	aca
# 0.5774	private_insurance
# 0.5758	health_coverage
#
# Pretrained:
# 0.8883	contraception
# 0.8489	contraceptives
# 0.7916	contraceptive
# 0.7277	iuds
# 0.7141	emergency_contraception
# 0.6993	pills
# 0.6951	abortions
# 0.6934	women_use
# 0.6933	abortion
# 0.6911	long_acting
#
# Our model:
# 0.8281	contraception
# 0.7493	contraceptives
# 0.6235	contraceptive
# 0.6115	pills
# 0.5883	abortion
# 0.5726	abortions
# 0.5697	pill
# 0.5528	reproductive_health
# 0.5305	pregnancy
# 0.5143	insurance_coverage
#
# Pretrained:
# 0.6884	romney_wo
# 0.6819	tax_records
# 0.6807	college_records
# 0.6563	romney_tax
# 0.6504	financial_disclosures
# 0.6503	tax_documents
# 0.6467	multiple_years
# 0.6263	obama_birth
# 0.6255	trump_tax
# 0.6195	medical_records
#
# Our model:
# 0.4869	release
# 0.4662	disclose
# 0.4621	releasing
# 0.4381	pay_taxes
# 0.4122	romney
# 0.4110	birth_certificate
# 0.4045	answer_questions
# 0.4042	medical_records
# 0.4035	mitt
# 0.4029	bain
#
# Pretrained:
# 0.8320	climate_change
# 0.7507	human_caused
# 0.7387	warming
# 0.7234	human_activity
# 0.7107	climate_scientists
# 0.6952	anthropogenic_global
# 0.6939	alarmists
# 0.6911	climate_crisis
# 0.6906	skeptic_guide
# 0.6899	scientific_consensus
#
# Our model:
# 0.8244	climate_change
# 0.7181	warming
# 0.5929	climate
# 0.5861	global_climate
# 0.5849	climate_scientists
# 0.5669	human_activity
# 0.5653	greenhouse_gases
# 0.5563	greenhouse_gas
# 0.5546	scientists
# 0.5532	climate_science
#
# Pretrained:
# 0.8320	global_warming
# 0.7031	global_climate
# 0.6997	human_caused
# 0.6588	climate_crisis
# 0.6565	human_activity
# 0.6541	intergovernmental_panel
# 0.6434	climate_science
# 0.6378	world_climate
# 0.6303	skeptic_guide
# 0.6290	scientific_consensus
#
# Our model:
# 0.8244	global_warming
# 0.6064	climate
# 0.6024	global_climate
# 0.5805	warming
# 0.5678	climate_science
# 0.5590	science
# 0.5223	scientists
# 0.5000	planet
# 0.4945	greenhouse_gas
# 0.4931	greenhouse_gases
#
# Pretrained:
# 0.6950	low_carbon
# 0.6939	renewable_energy
# 0.6902	renewables
# 0.6819	green_energy
# 0.6705	energy_efficiency
# 0.6662	clean_coal
# 0.6660	solar_energy
# 0.6479	new_energy
# 0.6444	alternative_energy
# 0.6368	solar_power
#
# Our model:
# 0.6231	renewable_energy
# 0.5797	renewables
# 0.5729	energy_efficiency
# 0.5672	solar_energy
# 0.5662	low_carbon
# 0.5069	solar_power
# 0.5037	new_energy
# 0.4972	alternative_energy
# 0.4862	green_energy
# 0.4852	technology
#
# Pretrained:
# 0.8427	illegal_immigrants
# 0.8257	unauthorized_immigrants
# 0.8221	million_undocumented
# 0.7906	young_undocumented
# 0.7825	illegal_aliens
# 0.7817	undocumented_workers
# 0.7799	illegals
# 0.7788	country_illegally
# 0.7701	million_illegal
# 0.7692	criminal_aliens
#
# Our model:
# 0.7886	illegal_immigrants
# 0.6985	undocumented
# 0.6905	immigrants
# 0.6862	deportation
# 0.6821	illegals
# 0.6783	illegal_aliens
# 0.6769	country_illegally
# 0.6674	unauthorized_immigrants
# 0.6378	deport
# 0.6177	million_undocumented
#
# Pretrained:
# 0.9597	conflict_heads
# 0.9499	africa_nigeria
# 0.9446	counterterrorism_nigeria
# 0.9413	africa_terrorism
# 0.9376	conflict_niger
# 0.9332	counterterrorism_heads
# 0.9280	counterterrorism_corruption
# 0.9271	religion_terrorism
# 0.9221	voting_terrorism
# 0.9214	nigeria_terrorism
#
# Our model:
# 0.9055	africa_nigeria
# 0.8970	conflict_heads
# 0.8829	counterterrorism_nigeria
# 0.8649	africa_terrorism
# 0.8455	nigeria_terrorism
# 0.8376	government_nigeria
# 0.8193	africa_politics
# 0.8065	counterterrorism_heads
# 0.7995	sub_saharan
# 0.7782	government_south
#
# Pretrained:
# 0.8624	agency_bonds
# 0.8601	us_equities
# 0.8555	us_treasuries
# 0.8498	foreign_purchases
# 0.8470	us_long
# 0.8449	us_securities
# 0.8424	us_bonds
# 0.8420	private_purchases
# 0.8395	term_assets
# 0.8380	agency_debt
#
# Our model:
# 0.6836	us_treasuries
# 0.6762	treasuries
# 0.6540	us_assets
# 0.6514	corporate_bonds
# 0.6464	agency_bonds
# 0.6271	us_equities
# 0.6165	us_long
# 0.6158	private_purchases
# 0.6110	foreign_demand
# 0.6061	chinese_purchases
#
# Pretrained:
# 0.6796	zero_bound
# 0.6512	taylor_rule
# 0.6260	fiscal_policy
# 0.6134	financial_markets
# 0.6079	budget_debt
# 0.6070	states_monetary
# 0.6059	markets_united
# 0.6057	states_budget
# 0.6052	japan_boj
# 0.6048	bank_ecb
#
# Our model:
# 0.5267	financial_markets
# 0.5127	federal_reserve
# 0.4961	budget_debt
# 0.4802	european_central
# 0.4746	fiscal_policy
# 0.4602	deficits_trade
# 0.4585	fed
# 0.4252	monetary
# 0.4016	bank_ecb
# 0.3994	bernanke
#
# Pretrained:
# 0.6455	china_economics
# 0.6374	markets_united
# 0.6352	deficits_economic
# 0.6352	states_budget
# 0.6346	economic_crises
# 0.6302	eurasia_financial
# 0.6285	states_monetary
# 0.6268	japan_boj
# 0.6257	policy_brazil
# 0.6231	development_monetary
#
# Our model:
# 0.5267	monetary_policy
# 0.4917	budget_debt
# 0.4883	markets
# 0.4658	deficits_trade
# 0.4382	economic_crises
# 0.4281	capital_flows
# 0.4178	federal_reserve
# 0.4034	economics
# 0.3970	banking
# 0.3832	china_economics
#
# Pretrained:
# 0.9341	vulgarity_profanity
# 0.9205	comments_containing
# 0.9147	advertising_vulgarity
# 0.9058	contain_spam
# 0.8967	discourteous_behavior
# 0.8910	remove_comments
# 0.7545	au_leaders
# 0.7282	remedies_available
# 0.7149	edit
# 0.7066	african_officials
#
# Our model:
# 0.8447	vulgarity_profanity
# 0.8299	advertising_vulgarity
# 0.8224	comments_containing
# 0.8128	contain_spam
# 0.7838	remove_comments
# 0.7686	discourteous_behavior
# 0.6817	personal_abusive
# 0.6549	edit
# 0.5785	privately_owned
# 0.5480	anti-semitism
#
# Pretrained:
# 0.9781	site_administrators
# 0.9747	repeat_offenders
# 0.9680	sole_discretion
# 0.9107	without_warning
# 0.7716	week_technology
# 0.7672	quick_round
# 0.6748	east_strategic
# 0.6533	well_make
# 0.6499	fact_vietnam
# 0.6497	members_may
#
# Our model:
# 0.9548	site_administrators
# 0.9488	repeat_offenders
# 0.9367	sole_discretion
# 0.8817	without_warning
# 0.6174	week_technology
# 0.6114	quick_round
# 0.5942	blocked
# 0.5680	members_may
# 0.5105	tribune_donors
# 0.5026	enforcement
#
# Pretrained:
# 0.7256	anti-zionism
# 0.6891	anti-israelism
# 0.6737	islamophobia
# 0.6670	au_leaders
# 0.6666	anti-jewish
# 0.6499	holocaust_denial
# 0.6415	central_feature
# 0.6412	advertising_vulgarity
# 0.6356	bigotry
# 0.6336	anti-semite
#
# Our model:
# 0.6956	personal_abusive
# 0.6135	advertising_vulgarity
# 0.5962	edit
# 0.5822	contain_spam
# 0.5757	threats
# 0.5554	remove_comments
# 0.5480	violence_racism
# 0.4869	reserve
# 0.4737	islamophobia
# 0.4625	web_site
#
# Pretrained:
# 0.8623	neoconservatives
# 0.8094	liberal_interventionists
# 0.7870	warmongers
# 0.7836	neoconservative
# 0.7771	liberal_interventionist
# 0.7691	official_washington
# 0.7532	war_hawks
# 0.7481	neo-conservative
# 0.7297	israeli_lobby
# 0.7290	war_party
#
# Our model:
# 0.7073	neoconservatives
# 0.6475	neoconservative
# 0.4955	warmongers
# 0.4841	hawks
# 0.4691	regime_change
# 0.4537	imperialist
# 0.4318	zionist
# 0.4272	zionists
# 0.4161	warmongering
# 0.4134	think_tanks
#
# Pretrained:
# 0.8004	vets
# 0.7329	combat_veterans
# 0.7319	military_families
# 0.7112	helping_veterans
# 0.7109	vietnam_veterans
# 0.7084	disabled_veterans
# 0.7080	many_veterans
# 0.7076	va
# 0.7042	veterans_affairs
# 0.7031	disabled_american
#
# Our model:
# 0.6983	vets
# 0.6743	veterans_affairs
# 0.6655	va
# 0.5347	service_members
# 0.5234	military_veterans
# 0.5025	ptsd
# 0.5015	active_duty
# 0.4955	homeless
# 0.4888	families
# 0.4870	post-traumatic_stress
#
# Pretrained:
# 0.7521	faculty_members
# 0.7434	faculty
# 0.7240	students
# 0.7104	university_professors
# 0.6980	administrators
# 0.6933	undergraduates
# 0.6795	profs
# 0.6787	college_professors
# 0.6776	law_schools
# 0.6763	graduate_students
#
# Our model:
# 0.6667	faculty
# 0.6370	students
# 0.6112	administrators
# 0.5995	campuses
# 0.5604	faculty_members
# 0.5526	colleges
# 0.5517	campus
# 0.5479	academic
# 0.5387	universities
# 0.5353	law_school
#
# Pretrained:
# 0.7782	islamic_extremists
# 0.7565	jihadi
# 0.7557	jihadi_groups
# 0.7525	foreign_fighters
# 0.7505	takfiri
# 0.7485	sunni_extremists
# 0.7473	terror_groups
# 0.7407	isis_al
# 0.7404	islamic_terrorists
# 0.7385	global_jihad
#
# Our model:
# 0.6158	jihadi
# 0.5663	isis
# 0.5636	terrorists
# 0.5427	al_qaeda
# 0.5422	extremist_groups
# 0.5335	foreign_fighters
# 0.5312	extremists
# 0.5222	terrorist_groups
# 0.4937	islamic_extremists
# 0.4924	isil
#
# Pretrained:
# 0.7698	internal_revenue
# 0.7172	lois_lerner
# 0.6720	tax_exempt
# 0.6684	i.r.s.
# 0.6535	irs_official
# 0.6484	irs_targeting
# 0.6434	obama_irs
# 0.6395	conservative_groups
# 0.6391	extra_scrutiny
# 0.6328	irs_agents
#
# Our model:
# 0.6743	internal_revenue
# 0.5687	tax_exempt
# 0.5618	conservative_groups
# 0.4616	inspector_general
# 0.4434	tea_party
# 0.4280	justice_department
# 0.4057	agency
# 0.3972	lois_lerner
# 0.3846	audit
# 0.3806	lerner
#
# Pretrained:
# 0.7290	economic_justice
# 0.6677	intersectional
# 0.6552	anti-racism
# 0.6545	intersectionality
# 0.6451	intellectual_diversity
# 0.6371	women_movement
# 0.6286	activists_like
# 0.6269	social_activism
# 0.6250	white_identity
# 0.6249	men_rights
#
# Our model:
# 0.5031	activists
# 0.4528	warriors
# 0.4443	environmental
# 0.4334	feminist
# 0.4317	ecological
# 0.4314	movement
# 0.4268	economic_justice
# 0.4236	social
# 0.4180	equality
# 0.4171	activist
#
# Pretrained:
# 0.7275	politically_correct
# 0.7091	cultural_marxism
# 0.7089	incivility
# 0.7054	agitprop
# 0.7032	correctness
# 0.7027	toxic_masculinity
# 0.7023	yale_porn
# 0.6973	anti-muslim_bigotry
# 0.6967	sjws
# 0.6961	cultural_marxist
#
# Our model:
# 0.5534	politically_correct
# 0.4477	identity_politics
# 0.4322	islamophobia
# 0.4197	intolerance
# 0.4128	college_fix
# 0.4095	elitist
# 0.4063	twitter_image
# 0.4022	culture
# 0.4011	college_campuses
# 0.3900	facebook_follow
#
# Pretrained:
# 0.7718	msm
# 0.7553	mainstream_press
# 0.7465	liberal_media
# 0.7374	corporate_media
# 0.7331	news_media
# 0.7268	main_stream
# 0.7254	establishment_media
# 0.7200	mainstream_news
# 0.7162	called_mainstream
# 0.7153	us_media
#
# Our model:
# 0.6460	media
# 0.6356	news_media
# 0.6306	msm
# 0.5991	liberal_media
# 0.5799	corporate_media
# 0.5432	outlets
# 0.5008	western_media
# 0.4990	media_outlets
# 0.4913	news_outlets
# 0.4824	american_media
#
# Pretrained:
# 0.8370	hillary_clinton
# 0.8195	clinton
# 0.6946	clintons
# 0.6939	like_hillary
# 0.6840	clinton_campaign
# 0.6835	crooked_hillary
# 0.6699	mrs._clinton
# 0.6656	bernie
# 0.6567	see_hillary
# 0.6567	think_hillary
#
# Our model:
# 0.7865	clinton
# 0.7817	hillary_clinton
# 0.6325	clinton_campaign
# 0.6065	clintons
# 0.5725	sanders
# 0.5692	bernie
# 0.5567	bernie_sanders
# 0.5454	mrs._clinton
# 0.5326	obama
# 0.5282	trump
#
# Pretrained:
# 0.7835	bush_tax
# 0.7509	cutting_taxes
# 0.7235	wealthiest_americans
# 0.7097	cut_taxes
# 0.7044	raising_taxes
# 0.7041	tax_increases
# 0.6913	trillion_tax
# 0.6798	unfunded_tax
# 0.6791	cuts_expire
# 0.6787	cutting_spending
#
# Our model:
# 0.6874	bush_tax
# 0.6066	tax_increases
# 0.5851	cut_taxes
# 0.5844	raising_taxes
# 0.5833	cuts
# 0.5662	tax_breaks
# 0.5616	bush_era
# 0.5601	wealthiest_americans
# 0.5509	cutting_taxes
# 0.5412	spending_cuts

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# Pretrained:
# 0.8771	death_tax
# 0.8563	richest_americans
# 0.8549	inheritance_tax
# 0.8509	surtax
# 0.8478	alternative_minimum
# 0.8466	top_tax
# 0.8318	high_earners
# 0.8283	trillion_tax
# 0.8262	wealthiest_americans
# 0.8240	increasing_taxes
#
# Our model:
# 0.7084	alternative_minimum
# 0.6656	top_tax
# 0.6535	individual_tax
# 0.6410	marginal_tax
# 0.6358	richest_americans
# 0.6298	corporate_taxes
# 0.6269	wealthiest_americans
# 0.6236	earners
# 0.6222	percent_tax
# 0.6211	high_earners
#
# Pretrained:
# 0.9386	inheritance_tax
# 0.8987	surtax
# 0.8905	wealthy_tax
# 0.8858	repeals_obamacare
# 0.8810	alternative_minimum
# 0.8799	marriage_penalty
# 0.8772	closing_loopholes
# 0.8771	estate_tax
# 0.8754	estate_taxes
# 0.8734	obamacare_taxes
#
# Our model:
# 0.7840	cuts_taxes
# 0.7756	regressive_tax
# 0.7708	amt
# 0.7667	surtax
# 0.7648	double_taxation
# 0.7613	marriage_penalty
# 0.7592	top_earners
# 0.7578	corporate_rate
# 0.7574	middle_people
# 0.7568	fica

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# Pretrained:
# 0.8351	work_visas
# 0.8273	people_seeking
# 0.8123	legal_immigrants
# 0.8114	hire_illegal
# 0.8063	young_undocumented
# 0.8009	border_crossers
# 0.8003	immigration_agents
# 0.7990	legal_residents
# 0.7986	many_immigrants
# 0.7981	undocumented_people
#
# Our model:
# 0.6229	million_undocumented
# 0.6108	million_illegal
# 0.6038	work_permits
# 0.6014	unauthorized_immigrants
# 0.5839	legal_immigrants
# 0.5711	u.s._illegally
# 0.5701	central_americans
# 0.5650	country_illegally
# 0.5641	immigrant_workers
# 0.5586	illegals
#
# Pretrained:
# 0.8451	illegals
# 0.8002	illegal_immigrants
# 0.7885	criminal_aliens
# 0.7825	undocumented_immigrants
# 0.7740	illegal_immigrant
# 0.7723	unauthorized_immigrants
# 0.7628	million_illegal
# 0.7517	criminal_illegal
# 0.7504	border_crossers
# 0.7442	deporting
#
# Our model:
# 0.7391	illegals
# 0.6902	illegal_immigrants
# 0.6783	undocumented_immigrants
# 0.6461	undocumented
# 0.6142	deportation
# 0.6137	illegal_immigrant
# 0.6035	country_illegally
# 0.6024	aliens
# 0.6002	deporting
# 0.5971	unauthorized_immigrants
#
# Pretrained:
# 0.8546	iirira
# 0.8451	called_dreamers
# 0.8387	million_illegals
# 0.8373	executive_amnesty
# 0.8361	immigration_reforms
# 0.8345	young_illegal
# 0.8331	immigration_advocates
# 0.8292	young_undocumented
# 0.8268	undocumented_children
# 0.8255	family_based
#
# Our model:
# 0.7335	student_visas
# 0.7318	stop_right
# 0.7284	government_employment
# 0.7282	add_ons
# 0.7258	rich_guys
# 0.7253	cuck
# 0.7225	fellow_citizen
# 0.7211	boneheaded
# 0.7210	sometime_soon
# 0.7181	norquist_said

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare	0, 0, 0,
# Pretrained:
# 0.8302	aca
# 0.8285	affordable_care
# 0.7863	health_law
# 0.7632	act_aca
# 0.7479	obamacare_insurance
# 0.7416	obamacare_would
# 0.7394	patient_protection
# 0.7364	republican_plan
# 0.7360	healthcare_law
# 0.7340	care_law
#
# Our model:
# 0.7311	affordable_care
# 0.7148	aca
# 0.6139	health_law
# 0.5942	health_insurance
# 0.5689	individual_mandate
# 0.5337	buy_insurance
# 0.5329	health_care
# 0.5301	care_law
# 0.5239	obamacare_would
# 0.5212	republican_plan
#
# aca	1, 0, 0,
# Pretrained:
# 0.8302	obamacare
# 0.8112	affordable_care
# 0.7640	individual_mandate
# 0.7463	health_law
# 0.7154	act_aca
# 0.7030	patient_protection
# 0.6975	obamacare_insurance
# 0.6948	healthcare_law
# 0.6799	buy_health
# 0.6786	obamacare_would
#
# Our model:
# 0.7333	affordable_care
# 0.7148	obamacare
# 0.6786	individual_mandate
# 0.6139	health_law
# 0.5539	buy_health
# 0.5416	act_aca
# 0.5413	patient_protection
# 0.5307	health_insurance
# 0.5242	marketplaces
# 0.5177	care_law
#
# public_option	0, 1, 0,
# Pretrained:
# 0.7152	medicare_buy
# 0.6861	public_plan
# 0.6798	health_reform
# 0.6649	healthcare_reform
# 0.6599	graham_cassidy
# 0.6543	single_payer
# 0.6473	care_reform
# 0.6458	universal_coverage
# 0.6452	comprehensive_health
# 0.6428	healthcare_bill
#
# Our model:
# 0.4883	healthcare_reform
# 0.4837	government_run
# 0.4760	health_reform
# 0.4625	single_payer
# 0.4625	medicare_buy
# 0.4577	public_plan
# 0.4518	care_reform
# 0.4495	universal_coverage
# 0.4438	private_health
# 0.4412	health_care
#
# single_payer	1, 0, 0,
# Pretrained:
# 0.7089	universal_coverage
# 0.6919	universal_healthcare
# 0.6774	universal_health
# 0.6704	free_college
# 0.6649	socialized_medicine
# 0.6543	public_option
# 0.6377	sanders_plan
# 0.6228	health_care
# 0.6222	cost_control
# 0.6202	comprehensive_health
#
# Our model:
# 0.5625	universal_health
# 0.5280	universal_healthcare
# 0.4984	universal_coverage
# 0.4745	free_college
# 0.4656	health_care
# 0.4625	public_option
# 0.4448	socialized_medicine
# 0.4377	care_system
# 0.4268	national_health
# 0.4238	healthcare_system
#
# socialized_medicine	0, 0, 0,
# Pretrained:
# 0.7672	universal_healthcare
# 0.7619	like_obamacare
# 0.7597	socialistic
# 0.7479	life_counseling
# 0.7462	need_health
# 0.7448	healthcare_plan
# 0.7419	government_takeover
# 0.7390	expanding_coverage
# 0.7388	end_medicare
# 0.7350	universal_coverage
#
# Our model:
# 0.5856	universal_healthcare
# 0.5778	universal_coverage
# 0.5522	massachusetts_health
# 0.5477	insurance_system
# 0.5317	like_obamacare
# 0.5310	government_takeover
# 0.5310	socialistic
# 0.5297	healthcare_plan
# 0.5246	pre-obamacare
# 0.5240	need_health

# %%
cf('leftists')
cf('antifa')
# Out:
# leftists	0, 0, 0,
# Pretrained:
# 0.6805	called_liberals
# 0.6750	liberals
# 0.6546	america_hating
# 0.6530	sjws
# 0.6524	liberals_progressives
# 0.6519	left_wingers
# 0.6471	hate_mongers
# 0.6435	marxists
# 0.6434	radical_leftists
# 0.6414	upper_caste
#
# Our model:
# 0.4991	liberals
# 0.4579	socialists
# 0.4365	anarchists
# 0.4063	marxists
# 0.4045	libertarians
# 0.3875	conservatives
# 0.3787	progressives
# 0.3701	liberals_progressives
# 0.3648	far_left
# 0.3601	left_libertarians
#
# antifa	0, 0, 0,
# Pretrained:
# 0.7640	anti-fascist
# 0.7229	alt_left
# 0.7210	deray_mckesson
# 0.7154	blacklives_matter
# 0.7036	anti-fascists
# 0.7026	matter_protesters
# 0.6984	anti-trump_protesters
# 0.6881	black_bloc
# 0.6795	white_supremacists
# 0.6775	jason_kessler
#
# Our model:
# 0.5570	anti-fascist
# 0.5140	alt_left
# 0.5042	blacklives_matter
# 0.4968	deray_mckesson
# 0.4780	anti-fascists
# 0.4616	bamn
# 0.4616	white_supremacists
# 0.4560	black_bloc
# 0.4540	agitators
# 0.4539	matter_protesters

# %%
cf('guns')
# Out:
# guns	0, 0, 0,
# Pretrained:
# 0.7178	firearms
# 0.6305	gun_enthusiasts
# 0.6286	semi-automatic_weapons
# 0.6231	ammo
# 0.6207	handguns
# 0.6139	gun_laws
# 0.6128	buy_guns
# 0.6080	assault_rifles
# 0.6066	firearm
# 0.6060	semiautomatic_weapons
#
# Our model:
# 0.6705	firearms
# 0.5196	firearm
# 0.5026	gun_laws
# 0.4926	gun_owners
# 0.4859	ammo
# 0.4818	assault_weapons
# 0.4801	gun_violence
# 0.4760	rifles
# 0.4619	gun_ownership
# 0.4595	handguns

# %%
cf('trade')
# Out:
# trade	0, 0, 0,
# Pretrained:
# 0.5864	education_trade
# 0.5812	infrastructure_corporate
# 0.5559	actual_trade
# 0.5520	yen_carry
# 0.5515	trade_could
# 0.5504	investment_agreements
# 0.5465	corporate_regulation
# 0.5437	investment_flows
# 0.5435	u.s._goods
# 0.5382	corporate_governance
#
# Our model:
# 0.3897	investment
# 0.3667	markets
# 0.3588	china
# 0.3438	cap
# 0.3433	corporate_governance
# 0.3424	international_trade
# 0.3254	goods
# 0.3232	investment_agreements
# 0.3218	economic_ties
# 0.3174	trade_barriers

# %%
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
# Out:
# Pretrained:
# 0.8450	lyin_ted
# 0.8403	even_hillary
# 0.8385	little_marco
# 0.8378	el_trumpo
# 0.8374	attack_hillary
# 0.8372	vast_right
# 0.8359	wing_conspiracy
# 0.8349	calling_trump
# 0.8338	con_artist
# 0.8327	lyin
#
# Our model:
# 0.5950	nominee_hillary
# 0.5838	email_scandal
# 0.5793	democrat_hillary
# 0.5773	pathological_liar
# 0.5693	calling_trump
# 0.5682	like_hillary
# 0.5671	vast_right
# 0.5599	campaign_chair
# 0.5584	hillary_campaign
# 0.5541	el_trumpo
#
# Pretrained:
# 0.9466	little_marco
# 0.9024	lyin
# 0.8855	real_donald
# 0.8736	trump_calling
# 0.8733	typical_politician
# 0.8728	paladino
# 0.8698	really_likes
# 0.8696	small_hands
# 0.8695	called_romney
# 0.8688	palin_says
#
# Our model:
# 0.7302	little_marco
# 0.7218	heidi_cruz
# 0.7201	presidential_wannabe
# 0.7173	made_trump
# 0.7152	press_since
# 0.7134	mr._rubio
# 0.7121	still_trump
# 0.7083	billionaire_businessman
# 0.7076	real_donald
# 0.7037	malik_obama
#
# Pretrained:
# 0.9466	lyin_ted
# 0.9232	lyin
# 0.9134	even_donald
# 0.9115	real_donald
# 0.9049	ted_cruz.
# 0.9037	typical_politician
# 0.9032	called_romney
# 0.9018	trump_calling
# 0.8983	hitting_back
# 0.8941	romney_supporter
#
# Our model:
# 0.7302	lyin_ted
# 0.7236	like_ted
# 0.7183	possible_presidential
# 0.7120	chafing
# 0.7110	former_reality
# 0.7104	cruz.
# 0.7101	john_weaver
# 0.7058	gop_rival
# 0.7044	cage_match
# 0.7038	romney_supporter

# %%
cf('lgbt')
# Out:
# lgbt	0, 0, 0,
# Pretrained:
# 0.7207	gay_lesbian
# 0.6757	bisexual
# 0.6623	transgender_community
# 0.6552	lgbt_movement
# 0.6512	lgbt_community
# 0.6449	lesbian_rights
# 0.6414	lesbian_gay
# 0.6403	transgender
# 0.6371	transgender_issues
# 0.6366	bisexual_transgender
#
# Our model:
# 0.5122	gay_lesbian
# 0.4891	bisexual
# 0.4855	transgender
# 0.4829	gay
# 0.4712	lesbian
# 0.4516	sexual_orientation
# 0.4364	lgbt_community
# 0.4262	lesbian_gay
# 0.4063	gender_identity
# 0.4032	gay_rights
