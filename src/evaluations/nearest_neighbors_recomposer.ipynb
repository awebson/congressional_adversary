# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/3bins/pretrained/init.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'decomposer.Decomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Vocab size = 138,444

# %%
# base_dir = Path('../../results/news/validation')
base_dir = Path('../../results/3bins recomp/')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='*/epoch6.pt', recomposer=True)

print(deno_space.keys())
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# Loading ../../results/3bins recomp/clamp L1/epoch6.pt
# Loading ../../results/3bins recomp/L1/epoch6.pt
# Loading ../../results/3bins recomp/clamp L4/epoch6.pt
# Loading ../../results/3bins recomp/focus recomp/epoch6.pt
#
# dict_keys(['clamp L1/epoch6.pt', 'L1/epoch6.pt', 'clamp L4/epoch6.pt', 'focus recomp/epoch6.pt'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['clamp L1/epoch6.pt']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
    GD(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ====================================================================================================
#              Dataset             Rho       Reference      Delta >.02
# ====================================================================================================
#     EN-MTurk-771.txt         55.44%         52.84%           2.60%
#   EN-RW-STANFORD.txt         41.51%         45.33%          -3.83%
#    EN-SIMLEX-999.txt         26.10%         32.94%          -6.84%
#     EN-MTurk-287.txt         62.00%         59.11%           2.90%
#        EN-YP-130.txt         48.80%         50.70%               𝜀
#    EN-WS-353-SIM.txt         72.28%         68.44%           3.85%
#     EN-MEN-TR-3k.txt         60.98%         52.50%           8.48%
#    EN-WS-353-REL.txt         56.59%         44.72%          11.87%
#      EN-VERB-143.txt         23.71%         29.88%          -6.17%
#    EN-WS-353-ALL.txt         62.31%         58.14%           4.17%
#  EN-SimVerb-3500.txt         18.83%         26.27%          -7.45%
# Mean Delta = 0.6979%

# %%
GD('aca')

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# gun_violence	1, 0, 0,
# Pretrained:
# 0.7120	mass_shootings
# 0.6513	gun-related
# 0.6494	gun_deaths
# 0.6420	developed_peers
# 0.6395	school_shootings
# 0.6338	stricter_gun
# 0.6317	gun_ownership
# 0.6275	control_laws
# 0.6242	shootings
# 0.6238	america_gun
#
# Our model:
# 0.7041	mass_shootings
# 0.6413	gun_control
# 0.6155	guns
# 0.6093	gun_deaths
# 0.5999	gun_ownership
# 0.5757	shootings
# 0.5645	gun_laws
# 0.5488	nra
# 0.5450	sandy_hook
# 0.5423	mass_shooting
#
# single_payer	1, 0, 0,
# Pretrained:
# 0.7089	universal_coverage
# 0.6919	universal_healthcare
# 0.6774	universal_health
# 0.6704	free_college
# 0.6649	socialized_medicine
# 0.6543	public_option
# 0.6377	sanders_plan
# 0.6228	health_care
# 0.6222	cost_control
# 0.6202	comprehensive_health
#
# Our model:
# 0.6462	public_option
# 0.6372	health_care
# 0.5936	universal_health
# 0.5746	government_run
# 0.5509	universal_coverage
# 0.5449	private_insurance
# 0.5444	national_health
# 0.5411	care_system
# 0.5290	medicare
# 0.5109	private_insurers
#
# medicaid_expansion	0, 0, 0,
# Pretrained:
# 0.7897	obamacare_medicaid
# 0.7886	expand_medicaid
# 0.7818	expanding_medicaid
# 0.7655	expanded_medicaid
# 0.7500	medicaid_program
# 0.7497	medicaid
# 0.7004	health_law
# 0.6967	state_medicaid
# 0.6909	insurance_subsidies
# 0.6891	federal_health
#
# Our model:
# 0.7587	expand_medicaid
# 0.6950	medicaid
# 0.6818	federal_health
# 0.6747	aca
# 0.6711	obamacare
# 0.6656	expanded_medicaid
# 0.6384	uninsured
# 0.6342	affordable_care
# 0.6108	health_insurance
# 0.6081	health_law
#
# birth_control	1, 0, 0,
# Pretrained:
# 0.8290	contraception
# 0.8005	contraceptives
# 0.7594	contraceptive
# 0.6743	abortion
# 0.6636	iuds
# 0.6611	emergency_contraception
# 0.6598	abortifacients
# 0.6374	long_acting
# 0.6347	reproductive_health
# 0.6334	contraceptive_coverage
#
# Our model:
# 0.8542	contraception
# 0.8034	contraceptives
# 0.6850	abortion
# 0.6537	abortions
# 0.6181	contraceptive
# 0.5967	reproductive_health
# 0.5907	low_women
# 0.5902	family_planning
# 0.5820	pregnancy
# 0.5804	cancer_screenings
#
# tax_returns	1, 0, 0,
# Pretrained:
# 0.6483	tax_records
# 0.6323	college_records
# 0.6304	romney_wo
# 0.6284	romney_tax
# 0.6185	multiple_years
# 0.6005	hiding_something
# 0.6004	tax_documents
# 0.5936	financial_disclosures
# 0.5736	trump_taxes
# 0.5711	financial_disclosure
#
# Our model:
# 0.5226	release
# 0.4691	bain
# 0.4579	releasing
# 0.4530	offshore_accounts
# 0.4521	bain_capital
# 0.4484	disclose
# 0.4400	mitt
# 0.4330	mitt_romney
# 0.4000	republican_nominee
# 0.3986	romney
#
# global_warming	1, 0, 0,
# Pretrained:
# 0.8255	climate_change
# 0.7334	human_caused
# 0.6899	warming
# 0.6755	anthropogenic_global
# 0.6744	human_activity
# 0.6732	climate_crisis
# 0.6692	human_induced
# 0.6624	greenhouse_effect
# 0.6620	skeptic_guide
# 0.6575	climate_scientists
#
# Our model:
# 0.8253	climate_change
# 0.7771	warming
# 0.6890	climate
# 0.6744	climate_scientists
# 0.6266	global_climate
# 0.6136	human_activity
# 0.6057	greenhouse_gases
# 0.5927	human_caused
# 0.5885	climate_science
# 0.5736	intergovernmental_panel
#
# climate_change	0, 0, 0,
# Pretrained:
# 0.8255	global_warming
# 0.7080	human_caused
# 0.6769	global_climate
# 0.6734	human_induced
# 0.6595	called_climate
# 0.6582	human_activity
# 0.6564	intergovernmental_panel
# 0.6532	world_climate
# 0.6522	anthropogenic_global
# 0.6375	warming_planet
#
# Our model:
# 0.8253	global_warming
# 0.7103	climate
# 0.6887	global_climate
# 0.6605	warming
# 0.6308	intergovernmental_panel
# 0.5885	climate_science
# 0.5835	climate_scientists
# 0.5544	ipcc
# 0.5534	human_activity
# 0.5432	impacts
#
# clean_energy	0, 0, 0,
# Pretrained:
# 0.6108	renewable_energy
# 0.6012	green_energy
# 0.5973	energy_efficiency
# 0.5904	solar_energy
# 0.5880	clean_renewable
# 0.5860	renewables
# 0.5665	low_carbon
# 0.5652	lower_carbon
# 0.5648	wind_solar
# 0.5630	new_energy
#
# Our model:
# 0.7349	renewable_energy
# 0.6704	energy_efficiency
# 0.6681	renewables
# 0.6500	alternative_energy
# 0.5977	clean_coal
# 0.5895	low_carbon
# 0.5815	solar_power
# 0.5777	solar_energy
# 0.5747	technologies
# 0.5690	solar
#
# undocumented_immigrants	0, 1, 0,
# Pretrained:
# 0.7615	illegal_immigrants
# 0.7573	million_undocumented
# 0.7503	unauthorized_immigrants
# 0.7347	young_undocumented
# 0.7150	illegal_aliens
# 0.7006	immigrants
# 0.6988	million_unauthorized
# 0.6975	immigrants_living
# 0.6945	young_illegal
# 0.6933	called_dreamers
#
# Our model:
# 0.7589	illegal_immigrants
# 0.7360	undocumented
# 0.7093	deportation
# 0.6999	million_undocumented
# 0.6925	immigrants
# 0.6553	illegals
# 0.6506	deport
# 0.6505	legal_status
# 0.6478	country_illegally
# 0.6404	unauthorized_immigrants
#
# counterterrorism_wars	0, 0, 1,
# Pretrained:
# 0.9326	africa_nigeria
# 0.9240	conflict_heads
# 0.9058	counterterrorism_heads
# 0.9035	conflict_niger
# 0.9016	religion_terrorism
# 0.9012	voting_terrorism
# 0.9010	counterterrorism_corruption
# 0.8993	counterterrorism_nigeria
# 0.8960	africa_terrorism
# 0.8890	conflict_defense
#
# Our model:
# 0.9348	africa_nigeria
# 0.9013	conflict_heads
# 0.8967	africa_terrorism
# 0.8893	sub_saharan
# 0.8746	counterterrorism_nigeria
# 0.8423	africa_politics
# 0.8376	nigeria_terrorism
# 0.8294	counterterrorism_heads
# 0.8226	government_nigeria
# 0.8211	conflict_niger
#
# us_debt	0, 0, 0,
# Pretrained:
# 0.7474	term_assets
# 0.7446	us_equities
# 0.7415	agency_debt
# 0.7407	recorded_purchases
# 0.7401	foreign_securities
# 0.7368	russian_holdings
# 0.7367	treasury_portfolio
# 0.7307	us_treasuries
# 0.7294	official_investors
# 0.7287	private_purchases
#
# Our model:
# 0.8121	treasuries
# 0.7725	us_assets
# 0.7357	us_data
# 0.7167	us_equities
# 0.7154	us_securities
# 0.7120	tic_data
# 0.7019	holdings
# 0.6989	b
# 0.6959	purchases
# 0.6945	us_long
#
# monetary_policy	0, 0, 0,
# Pretrained:
# 0.6341	zero_bound
# 0.6049	taylor_rule
# 0.5671	markets_united
# 0.5642	states_budget
# 0.5604	forward_guidance
# 0.5595	deficits_united
# 0.5594	states_monetary
# 0.5584	japan_boj
# 0.5574	dual_mandate
# 0.5518	yellen
#
# Our model:
# 0.6313	financial_markets
# 0.5911	budget_debt
# 0.5568	fed
# 0.5523	quantitative_easing
# 0.5426	federal_reserve
# 0.5330	deficits_united
# 0.5301	european_central
# 0.5260	bernanke
# 0.5256	bank_ecb
# 0.5147	deficits_trade
#
# financial_markets	0, 0, 0,
# Pretrained:
# 0.5817	markets_united
# 0.5796	development_monetary
# 0.5792	policy_brazil
# 0.5782	china_economics
# 0.5746	europe_international
# 0.5719	states_monetary
# 0.5709	fuels_financial
# 0.5707	eurasia_financial
# 0.5693	states_budget
# 0.5686	europe_economics
#
# Our model:
# 0.6313	monetary_policy
# 0.6181	budget_debt
# 0.6148	economic_crises
# 0.5932	capital_flows
# 0.5886	deficits_united
# 0.5716	china_economics
# 0.5703	states_budget
# 0.5485	eurasia_monetary
# 0.5465	deficits_trade
# 0.5439	markets
#
# violence_racism	0, 0, 1,
# Pretrained:
# 0.9338	vulgarity_profanity
# 0.9162	comments_containing
# 0.9054	advertising_vulgarity
# 0.8926	contain_spam
# 0.8911	discourteous_behavior
# 0.8760	remove_comments
# 0.7433	au_leaders
# 0.7141	ensued—there
# 0.6907	international_scandal
# 0.6819	edit
#
# Our model:
# 0.8769	advertising_vulgarity
# 0.8685	contain_spam
# 0.8683	remove_comments
# 0.8612	personal_abusive
# 0.8471	edit
# 0.8080	privately_owned
# 0.7939	anti-semitism
# 0.7674	vulgarity_profanity
# 0.7568	discourteous_behavior
# 0.7501	comments_containing
#
# permanently_banned	0, 0, 1,
# Pretrained:
# 0.9687	site_administrators
# 0.9546	repeat_offenders
# 0.9524	sole_discretion
# 0.8788	without_warning
# 0.7501	week_technology
# 0.7466	quick_round
# 0.6451	east_strategic
# 0.6342	alive_send
# 0.6326	fact_vietnam
# 0.6324	expressly_prohibited
#
# Our model:
# 0.9353	site_administrators
# 0.9285	repeat_offenders
# 0.9227	sole_discretion
# 0.9193	without_warning
# 0.7645	blocked
# 0.7225	enforcement
# 0.6616	may
# 0.5852	policy
# 0.4880	quick_round
# 0.4530	week_technology
#
# anti-semitism	0, 0, 0,
# Pretrained:
# 0.6710	anti-zionism
# 0.6244	anti-israelism
# 0.6229	anti-jewish
# 0.6192	islamophobia
# 0.6148	au_leaders
# 0.6128	racism
# 0.5832	advertising_vulgarity
# 0.5795	racism_sexism
# 0.5759	jews_everywhere
# 0.5749	delegitimization
#
# Our model:
# 0.8607	personal_abusive
# 0.8513	contain_spam
# 0.8385	remove_comments
# 0.8376	advertising_vulgarity
# 0.8210	edit
# 0.7939	violence_racism
# 0.7612	privately_owned
# 0.7359	threats
# 0.6996	web_site
# 0.6683	reserve
#
# neocons	0, 0, 0,
# Pretrained:
# 0.7768	neoconservatives
# 0.7679	liberal_interventionist
# 0.7555	liberal_interventionists
# 0.6919	warmongers
# 0.6908	official_washington
# 0.6907	neoconservative
# 0.6850	war_hawks
# 0.6562	interventionists
# 0.6561	pers
# 0.6554	war_party
#
# Our model:
# 0.7044	neoconservatives
# 0.6105	neoconservative
# 0.5394	warmongers
# 0.4984	israel_lobby
# 0.4973	hawks
# 0.4676	liberal_interventionists
# 0.4624	official_washington
# 0.4618	regime_change
# 0.4526	cabal
# 0.4473	robert_kagan
#
# veterans	0, 0, 0,
# Pretrained:
# 0.7809	vets
# 0.7120	combat_veterans
# 0.7079	disabled_veterans
# 0.7063	helping_veterans
# 0.7023	veterans_affairs
# 0.6949	military_families
# 0.6944	local_veterans
# 0.6942	disabled_american
# 0.6921	many_veterans
# 0.6910	million_veterans
#
# Our model:
# 0.7321	veterans_affairs
# 0.7262	va
# 0.7142	vets
# 0.5751	veterans_administration
# 0.5664	ptsd
# 0.5639	post-traumatic_stress
# 0.5609	service_members
# 0.5376	active_duty
# 0.5354	foreign_wars
# 0.5278	va_medical
#
# professors	0, 0, 0,
# Pretrained:
# 0.6860	faculty
# 0.6798	students
# 0.6631	university_professors
# 0.6569	faculty_members
# 0.6533	college_professors
# 0.6505	deans
# 0.6449	profs
# 0.6181	uchicago
# 0.6163	law_schools
# 0.6162	law_professors
#
# Our model:
# 0.7534	faculty
# 0.7016	students
# 0.6574	academic
# 0.6539	administrators
# 0.6398	campus
# 0.6237	campuses
# 0.6170	student
# 0.6138	universities
# 0.5921	faculty_members
# 0.5847	undergraduate
#
# jihadists	0, 0, 0,
# Pretrained:
# 0.6833	jihadi_groups
# 0.6781	muslim_extremists
# 0.6714	takfiri
# 0.6714	isis_al
# 0.6700	islamic_extremists
# 0.6684	jihadi
# 0.6667	sunni_extremists
# 0.6593	islamic_terrorists
# 0.6555	terrorists
# 0.6553	islamist_fighters
#
# Our model:
# 0.6548	isis
# 0.6289	extremists
# 0.6273	jihadi
# 0.6254	terrorists
# 0.6156	al_qaeda
# 0.5944	islamic_state
# 0.5543	isil
# 0.5509	terror_groups
# 0.5476	terrorist
# 0.5445	islamist
#
# irs	0, 0, 0,
# Pretrained:
# 0.7581	internal_revenue
# 0.7022	lois_lerner
# 0.6699	irs_targeting
# 0.6511	irs_official
# 0.6507	i.r.s.
# 0.6430	obama_irs
# 0.6290	irs_agents
# 0.6263	tax_exempt
# 0.6247	irs_officials
# 0.6243	extra_scrutiny
#
# Our model:
# 0.6854	internal_revenue
# 0.6841	tax_exempt
# 0.6245	conservative_groups
# 0.5417	lois_lerner
# 0.5197	lerner
# 0.5039	audit
# 0.4585	tax_administration
# 0.4490	extra_scrutiny
# 0.4468	inspector_general
# 0.4464	irs_targeting
#
# social_justice	0, 0, 0,
# Pretrained:
# 0.6287	economic_justice
# 0.5979	anti-racism
# 0.5965	intersectional
# 0.5829	sjw
# 0.5814	intersectionality
# 0.5792	philadelphia_based
# 0.5639	environmental_stewardship
# 0.5629	men_rights
# 0.5625	intellectual_diversity
# 0.5623	activists_like
#
# Our model:
# 0.4558	economic_justice
# 0.4549	warriors
# 0.4349	equality
# 0.4287	activism
# 0.4002	feminism
# 0.3928	progressive
# 0.3906	feminists
# 0.3898	feminist
# 0.3872	oppressed
# 0.3855	warrior
#
# political_correctness	0, 0, 0,
# Pretrained:
# 0.6404	cultural_marxism
# 0.6327	yale_porn
# 0.6207	book_sex
# 0.6195	identity_politics
# 0.6187	toxic_masculinity
# 0.6107	politically_correct
# 0.6071	sjws
# 0.6064	gay_agenda
# 0.6055	nathan_harden
# 0.6051	destroying_america
#
# Our model:
# 0.5064	politically_correct
# 0.5062	nathan_harden
# 0.4922	gone_bad
# 0.4821	identity_politics
# 0.4630	yale_porn
# 0.4625	book_sex
# 0.4590	good_education
# 0.4470	racism
# 0.4185	multiculturalism
# 0.4155	safe_spaces
#
# mainstream_media	0, 0, 0,
# Pretrained:
# 0.7181	msm
# 0.7103	mainstream_press
# 0.6923	corporate_media
# 0.6734	liberal_media
# 0.6671	called_mainstream
# 0.6661	leftist_media
# 0.6617	establishment_press
# 0.6597	main_stream
# 0.6586	us_media
# 0.6574	establishment_media
#
# Our model:
# 0.6769	media
# 0.6509	msm
# 0.6110	outlets
# 0.5764	news_media
# 0.5592	liberal_media
# 0.5329	mainstream_news
# 0.5223	conservative_media
# 0.5039	corporate_media
# 0.4753	us_media
# 0.4740	media_outlets
#
# hillary	0, 0, 0,
# Pretrained:
# 0.8379	hillary_clinton
# 0.8080	clinton
# 0.6890	clintons
# 0.6791	like_hillary
# 0.6725	said_hillary
# 0.6712	crooked_hillary
# 0.6694	see_clinton
# 0.6600	hillary_campaign
# 0.6592	nominee_hillary
# 0.6586	see_hillary
#
# Our model:
# 0.7664	hillary_clinton
# 0.7154	clinton
# 0.6195	clinton_campaign
# 0.5860	clintons
# 0.5326	bernie_sanders
# 0.5280	bernie
# 0.5253	sanders
# 0.5055	democratic_presidential
# 0.5033	she
# 0.5022	hillary_rodham
#
# tax_cuts	0, 0, 0,
# Pretrained:
# 0.7336	bush_tax
# 0.7202	cutting_taxes
# 0.6933	wealthiest_americans
# 0.6722	unfunded_tax
# 0.6653	trillion_tax
# 0.6622	cut_taxes
# 0.6614	cuts_expire
# 0.6607	wealthy_tax
# 0.6539	large_tax
# 0.6505	unfunded_wars
#
# Our model:
# 0.7632	bush_tax
# 0.7232	wealthiest_americans
# 0.7092	raising_taxes
# 0.6861	cuts
# 0.6731	wealthy
# 0.6644	spending_cuts
# 0.6546	tax_increases
# 0.6471	raise_taxes
# 0.6373	bush_era
# 0.6356	cut_taxes

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# estate_tax	1.0, 0.0, 0.0, 	0, 0, 0,
# Pretrained:
# 0.8058	death_tax
# 0.7939	inheritance_tax
# 0.7891	alternative_minimum
# 0.7830	surtax
# 0.7819	richest_americans
# 0.7713	top_tax
# 0.7479	individual_tax
# 0.7476	trillion_tax
# 0.7456	marriage_penalty
# 0.7389	top_rate
#
# Our model:
# 0.6780	alternative_minimum
# 0.6644	death_tax
# 0.6573	richest_americans
# 0.6412	surtax
# 0.6225	individual_tax
# 0.6194	top_tax
# 0.6038	top_rate
# 0.5926	trillion_tax
# 0.5845	wealthiest_americans
# 0.5828	child_tax
#
# death_tax	0.0, 1.0, 0.0, 	0, 0, 0,
# Pretrained:
# 0.8740	inheritance_tax
# 0.8266	surtax
# 0.8179	estate_taxes
# 0.8133	wealthy_tax
# 0.8133	obamacare_taxes
# 0.8108	alternative_minimum
# 0.8090	cuts_expire
# 0.8088	personal_exemptions
# 0.8077	raises_taxes
# 0.8068	marriage_penalty
#
# Our model:
# 0.7584	inheritance_tax
# 0.7095	surtax
# 0.7038	obamacare_taxes
# 0.7026	personal_exemptions
# 0.7018	alternative_minimum
# 0.6932	temporary_tax
# 0.6921	estate_taxes
# 0.6852	high_earners
# 0.6835	raises_taxes
# 0.6813	cuts_expire

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# undocumented_workers	0, 0, 0,
# Pretrained:
# 0.7386	unauthorized_workers
# 0.7354	work_visas
# 0.7099	hire_illegal
# 0.7078	million_undocumented
# 0.7017	temporary_work
# 0.7002	young_undocumented
# 0.6967	million_unauthorized
# 0.6966	work_authorization
# 0.6951	young_illegal
# 0.6937	called_dreamers
#
# Our model:
# 0.4965	undocumented_immigrants
# 0.4793	illegal_immigrants
# 0.4724	illegals
# 0.4636	million_undocumented
# 0.4626	immigrants
# 0.4621	illegal_aliens
# 0.4607	guest_worker
# 0.4606	million_illegal
# 0.4555	legal_status
# 0.4524	unauthorized_immigrants
#
# illegal_aliens	0, 0, 0,
# Pretrained:
# 0.7453	illegal_immigrants
# 0.7422	illegals
# 0.7150	undocumented_immigrants
# 0.7089	criminal_illegal
# 0.6989	criminal_aliens
# 0.6969	illegal_immigrant
# 0.6916	million_illegal
# 0.6883	young_illegal
# 0.6855	unauthorized_immigrants
# 0.6716	million_immigrants
#
# Our model:
# 0.7651	illegals
# 0.7184	illegal_immigrants
# 0.6772	country_illegally
# 0.6574	deportation
# 0.6338	undocumented
# 0.6304	undocumented_immigrants
# 0.6291	deporting
# 0.6129	aliens
# 0.6056	deportations
# 0.6020	immigration_enforcement
#
# chain_migration	0, 0, 0,
# Pretrained:
# 0.7758	family_based
# 0.7758	million_illegals
# 0.7676	young_illegal
# 0.7648	immigration_advocates
# 0.7614	immigration_reforms
# 0.7574	immigration_plan
# 0.7560	iirira
# 0.7544	called_dreamers
# 0.7540	raise_act
# 0.7516	young_undocumented
#
# Our model:
# 0.5146	family_based
# 0.5087	anchor_babies
# 0.5041	million_unauthorized
# 0.5010	million_immigrants
# 0.5002	called_dreamers
# 0.4914	diversity_visa
# 0.4862	work_authorization
# 0.4818	young_illegal
# 0.4773	immigrants_living
# 0.4726	administrative_amnesty

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare	0, 0, 0,
# Pretrained:
# 0.8302	aca
# 0.8285	affordable_care
# 0.7863	health_law
# 0.7632	act_aca
# 0.7479	obamacare_insurance
# 0.7416	obamacare_would
# 0.7394	patient_protection
# 0.7364	republican_plan
# 0.7360	healthcare_law
# 0.7340	care_law
#
# Our model:
# 0.8479	affordable_care
# 0.8001	aca
# 0.7466	health_insurance
# 0.6947	individual_mandate
# 0.6769	buy_insurance
# 0.6711	medicaid_expansion
# 0.6679	repeal
# 0.6506	health_law
# 0.6501	insurance
# 0.6388	repealing
#
# aca	1, 0, 0,
# Pretrained:
# 0.8302	obamacare
# 0.8112	affordable_care
# 0.7640	individual_mandate
# 0.7463	health_law
# 0.7154	act_aca
# 0.7030	patient_protection
# 0.6975	obamacare_insurance
# 0.6948	healthcare_law
# 0.6799	buy_health
# 0.6786	obamacare_would
#
# Our model:
# 0.8008	affordable_care
# 0.8001	obamacare
# 0.7653	health_insurance
# 0.7269	individual_mandate
# 0.6985	buy_insurance
# 0.6971	individual_market
# 0.6836	health_plans
# 0.6815	insurance
# 0.6804	premiums
# 0.6747	medicaid_expansion
#
# public_option	0, 1, 0,
# Pretrained:
# 0.7152	medicare_buy
# 0.6861	public_plan
# 0.6798	health_reform
# 0.6649	healthcare_reform
# 0.6599	graham_cassidy
# 0.6543	single_payer
# 0.6473	care_reform
# 0.6458	universal_coverage
# 0.6452	comprehensive_health
# 0.6428	healthcare_bill
#
# Our model:
# 0.6462	single_payer
# 0.5747	private_insurance
# 0.5580	healthcare_reform
# 0.5510	health_reform
# 0.5500	health_care
# 0.5408	government_run
# 0.5328	care_reform
# 0.5300	insurance_plan
# 0.5113	insurance_industry
# 0.5024	affordable_health
#
# single_payer	1, 0, 0,
# Pretrained:
# 0.7089	universal_coverage
# 0.6919	universal_healthcare
# 0.6774	universal_health
# 0.6704	free_college
# 0.6649	socialized_medicine
# 0.6543	public_option
# 0.6377	sanders_plan
# 0.6228	health_care
# 0.6222	cost_control
# 0.6202	comprehensive_health
#
# Our model:
# 0.6462	public_option
# 0.6372	health_care
# 0.5936	universal_health
# 0.5746	government_run
# 0.5509	universal_coverage
# 0.5449	private_insurance
# 0.5444	national_health
# 0.5411	care_system
# 0.5290	medicare
# 0.5109	private_insurers
#
# socialized_medicine	0, 0, 0,
# Pretrained:
# 0.7672	universal_healthcare
# 0.7619	like_obamacare
# 0.7597	socialistic
# 0.7479	life_counseling
# 0.7462	need_health
# 0.7448	healthcare_plan
# 0.7419	government_takeover
# 0.7390	expanding_coverage
# 0.7388	end_medicare
# 0.7350	universal_coverage
#
# Our model:
# 0.4750	single_payer
# 0.4586	death_panels
# 0.4374	government_run
# 0.4355	universal_health
# 0.4335	public_insurance
# 0.4269	care_plan
# 0.4182	get_insurance
# 0.4172	public_option
# 0.4136	private_insurance
# 0.4133	health_savings

# %%
cf('leftists')
cf('antifa')
# Out:
# leftists	0.0, 0.0, 1.0, 	0, 0, 0,
# Pretrained:
# 0.6805	called_liberals
# 0.6750	liberals
# 0.6546	america_hating
# 0.6530	sjws
# 0.6524	liberals_progressives
# 0.6519	left_wingers
# 0.6471	hate_mongers
# 0.6435	marxists
# 0.6434	radical_leftists
# 0.6414	upper_caste
#
# Our model:
# 0.5139	liberals
# 0.5033	anarchists
# 0.4840	socialists
# 0.4603	libertarians
# 0.4417	progressives
# 0.4394	feminists
# 0.4227	fascists
# 0.4038	far_left
# 0.3890	marxists
# 0.3885	antifa
#
# antifa	0.0, 0.0, 1.0, 	0, 0, 0,
# Pretrained:
# 0.7640	anti-fascist
# 0.7229	alt_left
# 0.7210	deray_mckesson
# 0.7154	blacklives_matter
# 0.7036	anti-fascists
# 0.7026	matter_protesters
# 0.6984	anti-trump_protesters
# 0.6881	black_bloc
# 0.6795	white_supremacists
# 0.6775	jason_kessler
#
# Our model:
# 0.6267	anti-fascist
# 0.5781	blacklives_matter
# 0.5474	deray_mckesson
# 0.5315	agitators
# 0.5305	alt_left
# 0.5198	white_supremacists
# 0.5027	white_nationalists
# 0.5006	neo-nazis
# 0.4985	matter_protesters
# 0.4912	counter_protesters

# %%
cf('guns')
# Out:
# guns	0.8041, 0.1959, 0.0, 	0, 0, 0,
# Pretrained:
# 0.7178	firearms
# 0.6305	gun_enthusiasts
# 0.6286	semi-automatic_weapons
# 0.6231	ammo
# 0.6207	handguns
# 0.6139	gun_laws
# 0.6128	buy_guns
# 0.6080	assault_rifles
# 0.6066	firearm
# 0.6060	semiautomatic_weapons
#
# Our model:
# 0.6723	firearms
# 0.5448	weapons
# 0.4984	firearm
# 0.4766	handguns
# 0.4727	rifles
# 0.4707	gun_owners
# 0.4694	gun_laws
# 0.4691	assault_weapons
# 0.4626	ammo
# 0.4589	gun_control

# %%
cf('trade')
# Out:
# trade	0.0, 0.0, 1.0, 	0, 0, 0,
# Pretrained:
# 0.5864	education_trade
# 0.5812	infrastructure_corporate
# 0.5559	actual_trade
# 0.5520	yen_carry
# 0.5515	trade_could
# 0.5504	investment_agreements
# 0.5465	corporate_regulation
# 0.5437	investment_flows
# 0.5435	u.s._goods
# 0.5382	corporate_governance
#
# Our model:
# 0.8102	[PAD]
# 0.8091	china
# 0.8049	however
# 0.8048	yet
# 0.8039	united_states
# 0.8038	both
# 0.8032	much
# 0.8032	first
# 0.8029	though
# 0.8029	u.s.

# %%
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
# Out:
# crooked_hillary	0.8952, 0.1048, 0.0, 	0, 0, 0,
# Pretrained:
# 0.7717	lyin
# 0.7677	lyin_ted
# 0.7644	lying_media
# 0.7625	nasty_woman
# 0.7605	little_marco
# 0.7530	candidate_ever
# 0.7529	attack_hillary
# 0.7513	attacking_hillary
# 0.7499	fucking_moron
# 0.7467	el_trumpo
#
# Our model:
# 0.5719	lyin
# 0.5690	lyin_ted
# 0.5591	nasty_woman
# 0.5535	attacking_hillary
# 0.5503	candidate_ever
# 0.5473	nominee_hillary
# 0.5471	lying_media
# 0.5421	el_trumpo
# 0.5417	email_scandal
# 0.5349	attack_hillary
#
# lyin_ted	0.1624, 0.8376, 0.0, 	0, 1, 0,
# Pretrained:
# 0.8914	little_marco
# 0.8196	lyin
# 0.8062	small_hands
# 0.7978	ted_cruz.
# 0.7936	trump_calling
# 0.7881	real_donald
# 0.7807	cruz_wife
# 0.7804	snit
# 0.7803	still_trump
# 0.7776	typical_politician
#
# Our model:
# 0.7973	little_marco
# 0.6920	lyin
# 0.6821	still_trump
# 0.6733	cruz_wife
# 0.6720	heidi_cruz
# 0.6690	ted_cruz.
# 0.6656	small_hands
# 0.6641	made_trump
# 0.6585	real_donald
# 0.6580	birther_issue
#
# little_marco	0.7079, 0.2921, 0.0, 	0, 0, 0,
# Pretrained:
# 0.8914	lyin_ted
# 0.8575	lyin
# 0.8505	ted_cruz.
# 0.8434	even_donald
# 0.8349	real_donald
# 0.8236	birther_issue
# 0.8231	trump_calling
# 0.8220	like_jeb
# 0.8177	skidmore_flickr
# 0.8152	paladino
#
# Our model:
# 0.7973	lyin_ted
# 0.7493	ted_cruz.
# 0.7306	lyin
# 0.7264	even_donald
# 0.7232	birther_issue
# 0.7204	skidmore_flickr
# 0.7202	called_donald
# 0.7177	real_donald
# 0.7033	msnbc_joe
# 0.6931	typical_politician

# %%
cf('lgbt')
# Out:
# lgbt	0.9584, 0.0416, 0.0, 	0, 0, 0,
# Pretrained:
# 0.7207	gay_lesbian
# 0.6757	bisexual
# 0.6623	transgender_community
# 0.6552	lgbt_movement
# 0.6512	lgbt_community
# 0.6449	lesbian_rights
# 0.6414	lesbian_gay
# 0.6403	transgender
# 0.6371	transgender_issues
# 0.6366	bisexual_transgender
#
# Our model:
# 0.5417	transgender
# 0.5274	bisexual
# 0.5146	gay
# 0.5131	gay_lesbian
# 0.5064	lesbian
# 0.5037	lgbt_community
# 0.4802	sexual_orientation
# 0.4483	gender_identity
# 0.4444	trans
# 0.4329	lesbian_gay
