# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/PN/pretrained/init.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'decomposer.Decomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Vocab size = 138,443
# /home/webson/Research/congressional_adversary/src/data.py:56: RuntimeWarning: invalid value encountered in long_scalars
#   self.R_ratio = self.cono_freq[2] / (self.cono_freq[0] + self.cono_freq[2])

# %%
# base_dir = Path('../../results/PN/EWS_recomposer/overcorrect')
base_dir = Path('../../results/PN/GM2')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='*/epoch2.pt', recomposer=True, pretrained=False)

print(deno_space.keys())
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# Loading ../../results/PN/GM2/BS4096/epoch2.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# dict_keys(['BS4096 epoch2'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['BS4096 epoch2']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
#     GD(query)
    print(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ====================================================================================================
#              Dataset             Rho       Reference      Delta >.02
# ====================================================================================================
#     EN-MTurk-771.txt         19.07%         49.62%         -30.55%
#   EN-RW-STANFORD.txt         14.99%         44.62%         -29.63%
#    EN-SIMLEX-999.txt          7.22%         30.70%         -23.49%
#     EN-MTurk-287.txt         29.02%         56.33%         -27.31%
#        EN-YP-130.txt         14.97%         41.14%         -26.17%
#    EN-WS-353-SIM.txt         16.02%         63.87%         -47.86%
#     EN-MEN-TR-3k.txt         16.18%         47.34%         -31.16%
#    EN-WS-353-REL.txt         11.91%         41.71%         -29.80%
#      EN-VERB-143.txt         16.34%         29.87%         -13.54%
#    EN-WS-353-ALL.txt          7.40%         54.88%         -47.48%
#  EN-SimVerb-3500.txt          2.29%         25.61%         -23.33%
# Mean Delta = -30.0277%

# %%
GD('aca')

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# estate_tax
# Pretrained:
# 0.8771	death_tax
# 0.8563	richest_americans
# 0.8549	inheritance_tax
# 0.8509	surtax
# 0.8478	alternative_minimum
# 0.8466	top_tax
# 0.8318	high_earners
# 0.8283	trillion_tax
# 0.8262	wealthiest_americans
# 0.8240	increasing_taxes
#
# Our model:
# 0.9837	inheritance_tax
# 0.9820	death_tax
# 0.9802	high_earners
# 0.9791	top_tax
# 0.9791	increasing_taxes
# 0.9779	wealthiest_americans
# 0.9775	richest_americans
# 0.9769	trillion_tax
# 0.9765	marginal_tax
# 0.9765	large_tax
#
# death_tax
# Pretrained:
# 0.9386	inheritance_tax
# 0.8987	surtax
# 0.8905	wealthy_tax
# 0.8858	repeals_obamacare
# 0.8810	alternative_minimum
# 0.8799	marriage_penalty
# 0.8772	closing_loopholes
# 0.8771	estate_tax
# 0.8754	estate_taxes
# 0.8734	obamacare_taxes
#
# Our model:
# 0.9877	inheritance_tax
# 0.9820	estate_tax
# 0.9805	wealthy_tax
# 0.9796	increasing_taxes
# 0.9783	top_earners
# 0.9767	progressive_tax
# 0.9766	medicare_cuts
# 0.9763	surtax
# 0.9759	tax_hike
# 0.9751	give_tax

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# undocumented_workers
# Pretrained:
# 0.8351	work_visas
# 0.8273	people_seeking
# 0.8123	legal_immigrants
# 0.8114	hire_illegal
# 0.8063	young_undocumented
# 0.8009	border_crossers
# 0.8003	immigration_agents
# 0.7990	legal_residents
# 0.7986	many_immigrants
# 0.7981	undocumented_people
#
# Our model:
# 0.9910	undocumented
# 0.9880	illegal_immigrants
# 0.9879	country_legally
# 0.9876	country_illegally
# 0.9875	undocumented_children
# 0.9874	immigrant_children
# 0.9871	people_seeking
# 0.9867	legal_status
# 0.9855	employers
# 0.9854	called_dreamers
#
# illegal_aliens
# Pretrained:
# 0.8451	illegals
# 0.8002	illegal_immigrants
# 0.7885	criminal_aliens
# 0.7825	undocumented_immigrants
# 0.7740	illegal_immigrant
# 0.7723	unauthorized_immigrants
# 0.7628	million_illegal
# 0.7517	criminal_illegal
# 0.7504	border_crossers
# 0.7442	deporting
#
# Our model:
# 0.9881	illegal_immigrants
# 0.9876	illegals
# 0.9864	deporting
# 0.9844	illegal_immigrant
# 0.9834	deportations
# 0.9834	country_illegally
# 0.9833	deport
# 0.9824	deportation
# 0.9819	deported
# 0.9818	border_crossers
#
# chain_migration
# Pretrained:
# 0.8546	iirira
# 0.8451	called_dreamers
# 0.8387	million_illegals
# 0.8373	executive_amnesty
# 0.8361	immigration_reforms
# 0.8345	young_illegal
# 0.8331	immigration_advocates
# 0.8292	young_undocumented
# 0.8268	undocumented_children
# 0.8255	family_based
#
# Our model:
# 0.9751	called_dreamers
# 0.9748	million_illegals
# 0.9731	trump_proposed
# 0.9729	million_unauthorized
# 0.9726	immigration_advocates
# 0.9725	immigration_plan
# 0.9721	young_illegal
# 0.9720	amnesties
# 0.9720	legal_immigrants
# 0.9720	family_based

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare
# Pretrained:
# 0.8494	aca
# 0.8422	affordable_care
# 0.8105	health_law
# 0.7692	individual_mandate
# 0.7499	republican_plan
# 0.7449	healthcare_law
# 0.7422	care_law
# 0.7415	patient_protection
# 0.7365	ahca
# 0.7361	act_aca
#
# Our model:
# 0.9952	pass
# 0.9948	mandate
# 0.9947	healthcare
# 0.9947	act
# 0.9947	health_care
# 0.9944	eliminating
# 0.9940	tax
# 0.9940	delay
# 0.9940	passage
# 0.9939	would_end
#
# aca
# Pretrained:
# 0.8494	obamacare
# 0.8348	affordable_care
# 0.8132	health_law
# 0.8107	individual_mandate
# 0.7533	individual_market
# 0.7386	insurance_plans
# 0.7385	patient_protection
# 0.7379	preexisting_conditions
# 0.7357	obamacare_insurance
# 0.7342	health_insurance
#
# Our model:
# 0.9924	health_insurance
# 0.9921	health_law
# 0.9898	affordable_care
# 0.9894	individual_mandate
# 0.9886	repealing
# 0.9879	insurance_coverage
# 0.9875	new_health
# 0.9874	health_coverage
# 0.9869	repeal
# 0.9865	private_insurance
#
# public_option
# Pretrained:
# 0.7652	medicare_buy
# 0.7636	health_reform
# 0.7521	graham_cassidy
# 0.7472	ahca
# 0.7370	public_plan
# 0.7366	single_payer
# 0.7317	care_reform
# 0.7242	comprehensive_health
# 0.7219	gop_plan
# 0.7215	universal_coverage
#
# Our model:
# 0.9806	health_reform
# 0.9796	single_payer
# 0.9758	healthcare_reform
# 0.9755	universal_coverage
# 0.9752	care_reform
# 0.9747	government_run
# 0.9741	repealing_obamacare
# 0.9727	comprehensive_health
# 0.9721	affordable_health
# 0.9718	universal_health
#
# single_payer
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.9877	universal_health
# 0.9837	universal_coverage
# 0.9813	universal_healthcare
# 0.9809	national_health
# 0.9807	health_care
# 0.9805	free_college
# 0.9798	affordable_health
# 0.9796	government_run
# 0.9796	public_option
# 0.9783	seniors
#
# socialized_medicine
# Pretrained:
# 0.8503	government_takeover
# 0.8386	like_obamacare
# 0.8367	socialistic
# 0.8302	end_medicare
# 0.8254	moochers
# 0.8243	universal_healthcare
# 0.8230	healthcare_plan
# 0.8170	freeloaders
# 0.8139	need_health
# 0.8119	hardworking_americans
#
# Our model:
# 0.9909	socialistic
# 0.9905	death_panels
# 0.9891	big_government
# 0.9877	entitlement
# 0.9872	radical_agenda
# 0.9872	deadbeats
# 0.9872	convince_americans
# 0.9870	personal_responsibility
# 0.9867	socialized
# 0.9867	conservatives_would

# %%
cf('leftists')
cf('antifa')
# Out:
# leftists
# Pretrained:
# 0.7698	fascists
# 0.7664	left_wingers
# 0.7495	called_liberals
# 0.7465	sjws
# 0.7462	hard_left
# 0.7418	marxists
# 0.7388	liberals
# 0.7367	xenophobes
# 0.7362	rightists
# 0.7361	misogynists
#
# Our model:
# 0.9918	racists
# 0.9911	haters
# 0.9903	feminists
# 0.9900	socialists
# 0.9900	self_righteous
# 0.9900	morons
# 0.9900	intolerant
# 0.9896	fascists
# 0.9895	left_wingers
# 0.9894	fellow_travelers
#
# antifa
# Pretrained:
# 0.8327	anti-fascist
# 0.7933	blacklives_matter
# 0.7690	white_supremacists
# 0.7669	deray_mckesson
# 0.7646	alt_left
# 0.7633	oath_keepers
# 0.7610	neo-nazis
# 0.7603	agitators
# 0.7514	white_nationalists
# 0.7487	matter_protesters
#
# Our model:
# 0.9869	anti-fascist
# 0.9809	agitators
# 0.9809	neo-nazis
# 0.9807	kkk
# 0.9795	neo-nazi
# 0.9793	white_supremacists
# 0.9792	white_nationalists
# 0.9781	white_supremacist
# 0.9776	charlottesville
# 0.9772	klan

# %%
# cf('private_account')
# cf('personal_account')

# %%
cf('foreign_trade')
cf('international_trade')
# Out:
# foreign_trade
# Pretrained:
# 0.8142	goods_services
# 0.7943	u.s._products
# 0.7907	open_trade
# 0.7879	trade_investment
# 0.7851	lowering_tariffs
# 0.7826	financial_architecture
# 0.7814	increased_trade
# 0.7753	attracting_foreign
# 0.7741	world_trading
# 0.7729	expanding_trade
#
# Our model:
# 0.9941	industries
# 0.9939	trade
# 0.9936	benefiting
# 0.9935	bolstering
# 0.9934	businesses
# 0.9933	enhancing
# 0.9933	integration
# 0.9933	generating
# 0.9933	disadvantage
# 0.9933	encourage
#
# international_trade
# Pretrained:
# 0.6451	government_deficits
# 0.6242	legal_trade
# 0.6056	trade
# 0.5932	global_trade
# 0.5931	international_environmental
# 0.5825	investment_agreements
# 0.5808	digital_commerce
# 0.5803	trade_expansion
# 0.5786	international_commerce
# 0.5773	existing_trade
#
# Our model:
# 0.9923	agreements
# 0.9921	regulation
# 0.9919	trade
# 0.9913	enhancing
# 0.9911	comprehensive
# 0.9909	labor
# 0.9907	industries
# 0.9906	expanding
# 0.9906	ensuring
# 0.9904	standards

# %%
cf('drilling')
cf('energy_exploration')
# Out:
# drilling
# Pretrained:
# 0.8109	oil_drilling
# 0.7738	gas_drilling
# 0.7571	offshore_drilling
# 0.7439	anwr
# 0.7418	arctic_national
# 0.7312	offshore_oil
# 0.7085	arctic_refuge
# 0.7076	hydraulic_fracturing
# 0.6921	gas_development
# 0.6910	fracking
#
# Our model:
# 0.9928	oil_drilling
# 0.9888	public_lands
# 0.9884	energy_companies
# 0.9883	gas_industry
# 0.9873	gas_companies
# 0.9871	federal_lands
# 0.9863	wildlife_refuge
# 0.9863	gas_drilling
# 0.9859	oil_gas
# 0.9859	environmental_regulations
#
# energy_exploration
# Pretrained:
# 0.9205	new_offshore
# 0.9151	new_drilling
# 0.9112	deepwater_drilling
# 0.9100	gas_exploration
# 0.8952	federal_waters
# 0.8886	private_lands
# 0.8854	management_plans
# 0.8829	kxl
# 0.8809	drilling_sites
# 0.8799	new_fossil
#
# Our model:
# 0.9884	federal_lands
# 0.9881	gas_drilling
# 0.9880	gas_exploration
# 0.9872	road_building
# 0.9868	oil_drilling
# 0.9862	new_drilling
# 0.9841	forest_management
# 0.9837	gas_development
# 0.9836	public_lands
# 0.9834	drilling

# %%
cf('tort_reform')
# cf('lawsuit_abuse_reform')
# Out:
# tort_reform
# Pretrained:
# 0.8110	campaign_reform
# 0.8074	reform_proposal
# 0.8026	trial_lawyers
# 0.7989	reform_advocates
# 0.7983	consumer_groups
# 0.7948	ethics_reforms
# 0.7920	finance_laws
# 0.7910	school_vouchers
# 0.7900	bill_saying
# 0.7895	disclose_act
#
# Our model:
# 0.9839	legislative_efforts
# 0.9829	trial_lawyers
# 0.9825	federal_legislation
# 0.9818	legislation_aimed
# 0.9811	state_legislators
# 0.9809	insurance_industry
# 0.9808	reform_advocates
# 0.9807	care_reform
# 0.9806	legislation_like
# 0.9805	bills_like

# %%
cf('trial_lawyer')
cf('personal_injury')
# cf('injury_lawyer')
# cf('ambulance_chasers')
# Out:
# trial_lawyer
# Pretrained:
# 0.8495	criminal_defense
# 0.8442	buzbee
# 0.8280	raley
# 0.8277	paul_green
# 0.8211	tony_buzbee
# 0.8204	state_representative
# 0.8179	longtime_republican
# 0.8153	comer
# 0.8142	hotze
# 0.8100	hecht
#
# Our model:
# 0.9856	state_representative
# 0.9853	criminal_defense
# 0.9838	state_legislator
# 0.9833	practicing_law
# 0.9831	gubernatorial_candidate
# 0.9831	state_senator
# 0.9824	mckinney
# 0.9823	california_said
# 0.9816	said_karen
# 0.9813	defense_fund
#
# personal_injury
# Pretrained:
# 0.8911	civil_suits
# 0.8836	wrongful_death
# 0.8808	fraud_case
# 0.8776	successfully_argued
# 0.8667	attorney_fees
# 0.8611	civil_suit
# 0.8569	texas_civil
# 0.8566	case_involves
# 0.8551	attorneys_said
# 0.8549	private_attorney
#
# Our model:
# 0.9832	civil_suits
# 0.9822	attorney_fees
# 0.9819	wrongful_death
# 0.9817	fraud_case
# 0.9816	successfully_argued
# 0.9808	plaintiff
# 0.9805	criminal_defense
# 0.9802	civil_lawsuit
# 0.9799	local_district
# 0.9798	lawsuits_filed

# %%
# cf('corporate_transparency')
cf('corporate_accountability')
# Out:
# corporate_accountability
# Pretrained:
# 0.8881	photo_istockphoto
# 0.8860	putting_additional
# 0.8848	robert_kepple
# 0.8815	support_nonprofit
# 0.8808	laura_huffman
# 0.8765	nation_underperforming
# 0.8764	nb_staff
# 0.8760	john_esparza
# 0.8760	powerful_grassroots
# 0.8724	larry_soward
#
# Our model:
# 0.9844	said_adam
# 0.9843	nation_leading
# 0.9838	policy_group
# 0.9835	helped_produce
# 0.9829	said_fred
# 0.9828	based_group
# 0.9828	said_patrick
# 0.9826	said_steven
# 0.9825	said_jennifer
# 0.9825	says_paul

# %%
cf('school_choice')
# Out:
# school_choice
# Pretrained:
# 0.8459	school_vouchers
# 0.7874	pre_k
# 0.7657	charter_schools
# 0.7536	early_education
# 0.7499	school_voucher
# 0.7450	education_policy
# 0.7446	private_school
# 0.7440	pre-kindergarten
# 0.7408	parent_trigger
# 0.7376	standardized_testing
#
# Our model:
# 0.9825	school_vouchers
# 0.9806	charter_schools
# 0.9805	private_school
# 0.9777	vouchers
# 0.9776	public_education
# 0.9766	charter_school
# 0.9747	early_education
# 0.9743	local_control
# 0.9741	public_schools
# 0.9739	state_new

# %%
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
# Out:
# crooked_hillary
# Pretrained:
# 0.8450	lyin_ted
# 0.8403	even_hillary
# 0.8385	little_marco
# 0.8378	el_trumpo
# 0.8374	attack_hillary
# 0.8372	vast_right
# 0.8359	wing_conspiracy
# 0.8349	calling_trump
# 0.8338	con_artist
# 0.8327	lyin
#
# Our model:
# 0.9851	like_hillary
# 0.9846	con_artist
# 0.9845	calling_trump
# 0.9843	liar
# 0.9841	kellyanne_conway
# 0.9840	saying_trump
# 0.9835	vast_right
# 0.9830	bigly
# 0.9830	wing_conspiracy
# 0.9827	fucking_moron
#
# lyin_ted
# Pretrained:
# 0.9466	little_marco
# 0.9024	lyin
# 0.8855	real_donald
# 0.8736	trump_calling
# 0.8733	typical_politician
# 0.8728	paladino
# 0.8698	really_likes
# 0.8696	small_hands
# 0.8695	called_romney
# 0.8688	palin_says
#
# Our model:
# 0.9846	little_marco
# 0.9792	lyin
# 0.9751	heidi_cruz
# 0.9750	trump_calling
# 0.9750	crooked_hillary
# 0.9731	typical_politician
# 0.9724	woman_card
# 0.9721	presidential_wannabe
# 0.9716	called_romney
# 0.9715	gop_frontrunner
#
# little_marco
# Pretrained:
# 0.9466	lyin_ted
# 0.9232	lyin
# 0.9134	even_donald
# 0.9115	real_donald
# 0.9049	ted_cruz.
# 0.9037	typical_politician
# 0.9032	called_romney
# 0.9019	trump_calling
# 0.8983	hitting_back
# 0.8941	romney_supporter
#
# Our model:
# 0.9846	lyin_ted
# 0.9750	lyin
# 0.9680	called_romney
# 0.9674	real_donald
# 0.9672	woman_card
# 0.9656	trump_calling
# 0.9653	even_donald
# 0.9647	romney_supporter
# 0.9630	stupid_party
# 0.9626	candidate_mike

# %%
cf('lgbt')
# Out:
# lgbt
# Pretrained:
# 0.7943	gay_lesbian
# 0.7506	lgbt_community
# 0.7398	transgender
# 0.7358	bisexual
# 0.7317	glaad
# 0.7188	transgender_community
# 0.7158	transgender_rights
# 0.7138	lesbian_gay
# 0.7016	lgbt_movement
# 0.6988	lgbtq_community
#
# Our model:
# 0.9938	transgender
# 0.9930	civil_rights
# 0.9928	gay_rights
# 0.9927	lgbt_community
# 0.9923	lesbian
# 0.9919	discrimination
# 0.9912	transgender_rights
# 0.9903	transgender_community
# 0.9900	many_gay
# 0.9898	lgbt_movement

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# gun_violence
# Pretrained:
# 0.7665	mass_shootings
# 0.6997	gun_deaths
# 0.6910	school_shootings
# 0.6739	gun_control
# 0.6735	gun-related
# 0.6655	developed_peers
# 0.6653	america_gun
# 0.6652	mass_shooting
# 0.6619	shootings
# 0.6607	gun_laws
#
# Our model:
# 0.9880	mass_shootings
# 0.9847	gun_control
# 0.9847	shootings
# 0.9829	many_guns
# 0.9825	strong_indicator
# 0.9823	gun_laws
# 0.9822	mental_illness
# 0.9822	developed_peers
# 0.9806	violent_crime
# 0.9805	school_shootings
#
# single_payer
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.9877	universal_health
# 0.9837	universal_coverage
# 0.9813	universal_healthcare
# 0.9809	national_health
# 0.9807	health_care
# 0.9805	free_college
# 0.9798	affordable_health
# 0.9796	government_run
# 0.9796	public_option
# 0.9783	seniors
#
# medicaid_expansion
# Pretrained:
# 0.8240	obamacare_medicaid
# 0.8239	expanding_medicaid
# 0.8146	expand_medicaid
# 0.8130	expanded_medicaid
# 0.8066	medicaid_program
# 0.7914	medicaid
# 0.7896	health_law
# 0.7493	federal_health
# 0.7473	block_grant
# 0.7464	kynect
#
# Our model:
# 0.9831	medicaid
# 0.9825	federal_health
# 0.9811	expanding_medicaid
# 0.9804	medicaid_program
# 0.9799	expand_medicaid
# 0.9783	affordable_care
# 0.9769	health_law
# 0.9769	uninsured
# 0.9761	insurance_program
# 0.9748	federal_funding
#
# birth_control
# Pretrained:
# 0.8883	contraception
# 0.8489	contraceptives
# 0.7916	contraceptive
# 0.7277	iuds
# 0.7141	emergency_contraception
# 0.6993	pills
# 0.6951	abortions
# 0.6934	women_use
# 0.6933	abortion
# 0.6911	long_acting
#
# Our model:
# 0.9963	contraception
# 0.9894	pregnancy
# 0.9893	contraceptives
# 0.9891	abortion
# 0.9869	force_women
# 0.9868	women_would
# 0.9865	reproductive
# 0.9853	counseling
# 0.9850	life_saving
# 0.9849	doctors
#
# tax_returns
# Pretrained:
# 0.6884	romney_wo
# 0.6819	tax_records
# 0.6807	college_records
# 0.6563	romney_tax
# 0.6504	financial_disclosures
# 0.6503	tax_documents
# 0.6467	multiple_years
# 0.6263	obama_birth
# 0.6255	trump_tax
# 0.6195	medical_records
#
# Our model:
# 0.9854	tax_records
# 0.9842	hiding_something
# 0.9830	answer_questions
# 0.9826	come_clean
# 0.9826	revelations
# 0.9825	repeatedly_said
# 0.9822	trump_would
# 0.9820	release
# 0.9819	mr._trump
# 0.9819	disclosing
#
# global_warming
# Pretrained:
# 0.8320	climate_change
# 0.7507	human_caused
# 0.7387	warming
# 0.7234	human_activity
# 0.7107	climate_scientists
# 0.6952	anthropogenic_global
# 0.6939	alarmists
# 0.6911	climate_crisis
# 0.6906	skeptic_guide
# 0.6899	scientific_consensus
#
# Our model:
# 0.9987	climate_change
# 0.9972	climate
# 0.9963	scientists
# 0.9962	effects
# 0.9960	scale
# 0.9960	scientific
# 0.9959	poses
# 0.9959	dangers
# 0.9959	consequences
# 0.9958	warnings
#
# climate_change
# Pretrained:
# 0.8320	global_warming
# 0.7031	global_climate
# 0.6997	human_caused
# 0.6588	climate_crisis
# 0.6565	human_activity
# 0.6541	intergovernmental_panel
# 0.6434	climate_science
# 0.6378	world_climate
# 0.6303	skeptic_guide
# 0.6290	scientific_consensus
#
# Our model:
# 0.9987	global_warming
# 0.9986	climate
# 0.9974	challenges
# 0.9973	effects
# 0.9972	implications
# 0.9972	importance
# 0.9971	tangible
# 0.9971	difficulty
# 0.9971	possibilities
# 0.9971	uncertain
#
# clean_energy
# Pretrained:
# 0.6950	low_carbon
# 0.6939	renewable_energy
# 0.6902	renewables
# 0.6819	green_energy
# 0.6705	energy_efficiency
# 0.6662	clean_coal
# 0.6660	solar_energy
# 0.6479	new_energy
# 0.6444	alternative_energy
# 0.6368	solar_power
#
# Our model:
# 0.9858	energy_efficiency
# 0.9837	renewable_energy
# 0.9826	renewables
# 0.9823	alternative_energy
# 0.9821	transportation
# 0.9808	initiatives
# 0.9806	partnerships
# 0.9805	reductions
# 0.9803	next_decade
# 0.9799	subsidies
#
# undocumented_immigrants
# Pretrained:
# 0.8427	illegal_immigrants
# 0.8257	unauthorized_immigrants
# 0.8221	million_undocumented
# 0.7906	young_undocumented
# 0.7825	illegal_aliens
# 0.7817	undocumented_workers
# 0.7799	illegals
# 0.7788	country_illegally
# 0.7701	million_illegal
# 0.7692	criminal_aliens
#
# Our model:
# 0.9866	undocumented
# 0.9864	deportation
# 0.9853	immigration_laws
# 0.9837	young_undocumented
# 0.9834	undocumented_workers
# 0.9833	immigration_enforcement
# 0.9832	country_illegally
# 0.9831	called_dreamers
# 0.9829	federal_law
# 0.9827	obama_era
#
# counterterrorism_wars
# Pretrained:
# 0.9597	conflict_heads
# 0.9499	africa_nigeria
# 0.9446	counterterrorism_nigeria
# 0.9413	africa_terrorism
# 0.9376	conflict_niger
# 0.9332	counterterrorism_heads
# 0.9280	counterterrorism_corruption
# 0.9271	religion_terrorism
# 0.9221	voting_terrorism
# 0.9214	nigeria_terrorism
#
# Our model:
# 0.9949	conflict_heads
# 0.9943	africa_nigeria
# 0.9934	counterterrorism_nigeria
# 0.9929	counterterrorism_heads
# 0.9911	africa_terrorism
# 0.9907	government_nigeria
# 0.9893	conflict_niger
# 0.9891	counterterrorism_corruption
# 0.9870	religion_terrorism
# 0.9860	conflict_politics
#
# us_debt
# Pretrained:
# 0.8624	agency_bonds
# 0.8601	us_equities
# 0.8555	us_treasuries
# 0.8498	foreign_purchases
# 0.8470	us_long
# 0.8449	us_securities
# 0.8424	us_bonds
# 0.8420	private_purchases
# 0.8395	term_assets
# 0.8380	agency_debt
#
# Our model:
# 0.9858	us_assets
# 0.9854	us_treasuries
# 0.9846	us_bonds
# 0.9832	us_corporate
# 0.9830	treasuries
# 0.9805	dollar_denominated
# 0.9799	us_equities
# 0.9798	world_central
# 0.9797	treasury_bonds
# 0.9776	dollar_value
#
# monetary_policy
# Pretrained:
# 0.6796	zero_bound
# 0.6512	taylor_rule
# 0.6260	fiscal_policy
# 0.6134	financial_markets
# 0.6079	budget_debt
# 0.6070	states_monetary
# 0.6059	markets_united
# 0.6057	states_budget
# 0.6052	japan_boj
# 0.6048	bank_ecb
#
# Our model:
# 0.9700	financial_markets
# 0.9650	fiscal_policy
# 0.9625	federal_reserve
# 0.9612	quantitative_easing
# 0.9611	european_central
# 0.9587	looser
# 0.9585	monetary
# 0.9582	policy_response
# 0.9569	fed
# 0.9565	macroeconomic
#
# financial_markets
# Pretrained:
# 0.6455	china_economics
# 0.6374	markets_united
# 0.6352	deficits_economic
# 0.6352	states_budget
# 0.6346	economic_crises
# 0.6302	eurasia_financial
# 0.6285	states_monetary
# 0.6268	japan_boj
# 0.6257	policy_brazil
# 0.6231	development_monetary
#
# Our model:
# 0.9766	financial_system
# 0.9766	global_financial
# 0.9766	markets
# 0.9763	banking
# 0.9761	financial_crisis
# 0.9760	capital_markets
# 0.9758	monetary
# 0.9753	global_economic
# 0.9752	fed
# 0.9746	great_financial
#
# violence_racism
# Pretrained:
# 0.9341	vulgarity_profanity
# 0.9205	comments_containing
# 0.9147	advertising_vulgarity
# 0.9058	contain_spam
# 0.8967	discourteous_behavior
# 0.8910	remove_comments
# 0.7545	au_leaders
# 0.7282	remedies_available
# 0.7149	edit
# 0.7066	african_officials
#
# Our model:
# 0.9871	edit
# 0.9871	advertising_vulgarity
# 0.9852	contain_spam
# 0.9839	remove_comments
# 0.9795	privately_owned
# 0.9720	anti-semitism
# 0.9625	web_site
# 0.9601	personal_abusive
# 0.9517	reserve
# 0.9365	caps
#
# permanently_banned
# Pretrained:
# 0.9781	site_administrators
# 0.9747	repeat_offenders
# 0.9680	sole_discretion
# 0.9107	without_warning
# 0.7716	week_technology
# 0.7672	quick_round
# 0.6748	east_strategic
# 0.6533	well_make
# 0.6499	fact_vietnam
# 0.6497	members_may
#
# Our model:
# 0.9943	repeat_offenders
# 0.9928	site_administrators
# 0.9926	sole_discretion
# 0.9876	without_warning
# 0.8911	blocked
# 0.8599	enforcement
# 0.8277	temporarily_blocked
# 0.8258	texas_voter
# 0.8240	campus_carry
# 0.8227	new_texas
#
# anti-semitism
# Pretrained:
# 0.7256	anti-zionism
# 0.6891	anti-israelism
# 0.6737	islamophobia
# 0.6670	au_leaders
# 0.6666	anti-jewish
# 0.6499	holocaust_denial
# 0.6415	central_feature
# 0.6412	advertising_vulgarity
# 0.6356	bigotry
# 0.6336	anti-semite
#
# Our model:
# 0.9855	web_site
# 0.9812	reserve
# 0.9781	personal_abusive
# 0.9776	edit
# 0.9720	violence_racism
# 0.9687	threats
# 0.9684	advertising_vulgarity
# 0.9679	privately_owned
# 0.9670	users
# 0.9667	tolerance
#
# neocons
# Pretrained:
# 0.8623	neoconservatives
# 0.8094	liberal_interventionists
# 0.7870	warmongers
# 0.7836	neoconservative
# 0.7771	liberal_interventionist
# 0.7691	official_washington
# 0.7532	war_hawks
# 0.7481	neo-conservative
# 0.7297	israeli_lobby
# 0.7290	war_party
#
# Our model:
# 0.9944	neoconservatives
# 0.9933	warmongers
# 0.9914	neoconservative
# 0.9892	warmonger
# 0.9878	warmongering
# 0.9876	globalists
# 0.9875	sycophants
# 0.9873	pro-war
# 0.9872	like_john
# 0.9872	america_enemies
#
# veterans
# Pretrained:
# 0.8004	vets
# 0.7329	combat_veterans
# 0.7319	military_families
# 0.7112	helping_veterans
# 0.7109	vietnam_veterans
# 0.7084	disabled_veterans
# 0.7080	many_veterans
# 0.7076	va
# 0.7042	veterans_affairs
# 0.7031	disabled_american
#
# Our model:
# 0.9937	vets
# 0.9904	military_service
# 0.9902	care
# 0.9897	volunteer
# 0.9896	returning_veterans
# 0.9896	receiving
# 0.9896	full_time
# 0.9895	elderly
# 0.9895	employees
# 0.9895	rolls
#
# professors
# Pretrained:
# 0.7521	faculty_members
# 0.7434	faculty
# 0.7240	students
# 0.7104	university_professors
# 0.6980	administrators
# 0.6933	undergraduates
# 0.6795	profs
# 0.6787	college_professors
# 0.6776	law_schools
# 0.6763	graduate_students
#
# Our model:
# 0.9938	students
# 0.9935	faculty
# 0.9928	campus
# 0.9928	student
# 0.9928	college_students
# 0.9924	college
# 0.9920	administrators
# 0.9920	harvard
# 0.9917	teaching
# 0.9916	academic
#
# jihadists
# Pretrained:
# 0.7782	islamic_extremists
# 0.7565	jihadi
# 0.7557	jihadi_groups
# 0.7525	foreign_fighters
# 0.7505	takfiri
# 0.7485	sunni_extremists
# 0.7473	terror_groups
# 0.7407	isis_al
# 0.7404	islamic_terrorists
# 0.7385	global_jihad
#
# Our model:
# 0.9968	jihadi
# 0.9966	militant
# 0.9965	murderous
# 0.9963	terrorists
# 0.9963	self_proclaimed
# 0.9963	isis
# 0.9962	radicalized
# 0.9961	terrorist
# 0.9961	fighters
# 0.9961	terrorist_group
#
# irs
# Pretrained:
# 0.7698	internal_revenue
# 0.7172	lois_lerner
# 0.6720	tax_exempt
# 0.6684	i.r.s.
# 0.6535	irs_official
# 0.6484	irs_targeting
# 0.6434	obama_irs
# 0.6395	conservative_groups
# 0.6391	extra_scrutiny
# 0.6328	irs_agents
#
# Our model:
# 0.9917	internal_revenue
# 0.9842	paperwork
# 0.9842	taxpayer_funded
# 0.9841	extra_scrutiny
# 0.9835	complaint
# 0.9835	watchdog
# 0.9834	additional_scrutiny
# 0.9828	file
# 0.9826	fraud
# 0.9825	alleging
#
# social_justice
# Pretrained:
# 0.7290	economic_justice
# 0.6677	intersectional
# 0.6552	anti-racism
# 0.6545	intersectionality
# 0.6451	intellectual_diversity
# 0.6371	women_movement
# 0.6286	activists_like
# 0.6269	social_activism
# 0.6250	white_identity
# 0.6249	men_rights
#
# Our model:
# 0.9950	embodied
# 0.9946	champions
# 0.9945	liberals
# 0.9942	culture
# 0.9942	racial
# 0.9942	liberal
# 0.9941	faith
# 0.9941	contemporary
# 0.9941	hypocritical
# 0.9941	passionate
#
# political_correctness
# Pretrained:
# 0.7275	politically_correct
# 0.7091	cultural_marxism
# 0.7089	incivility
# 0.7054	agitprop
# 0.7032	correctness
# 0.7027	toxic_masculinity
# 0.7023	yale_porn
# 0.6973	anti-muslim_bigotry
# 0.6967	sjws
# 0.6961	cultural_marxist
#
# Our model:
# 0.9953	hate
# 0.9953	hateful
# 0.9949	hatred
# 0.9946	ignorant
# 0.9945	racism
# 0.9945	racist
# 0.9943	unhinged
# 0.9942	idiocy
# 0.9941	hating
# 0.9941	bigotry
#
# mainstream_media
# Pretrained:
# 0.7718	msm
# 0.7553	mainstream_press
# 0.7465	liberal_media
# 0.7374	corporate_media
# 0.7331	news_media
# 0.7268	main_stream
# 0.7254	establishment_media
# 0.7200	mainstream_news
# 0.7162	called_mainstream
# 0.7153	us_media
#
# Our model:
# 0.9976	propaganda
# 0.9975	pathetic
# 0.9972	truth
# 0.9972	nonsense
# 0.9971	smear
# 0.9971	stupid
# 0.9971	pretending
# 0.9970	ridiculous
# 0.9969	nasty
# 0.9968	obsession
#
# hillary
# Pretrained:
# 0.8370	hillary_clinton
# 0.8195	clinton
# 0.6946	clintons
# 0.6939	like_hillary
# 0.6840	clinton_campaign
# 0.6835	crooked_hillary
# 0.6699	mrs._clinton
# 0.6656	bernie
# 0.6567	see_hillary
# 0.6567	think_hillary
#
# Our model:
# 0.9946	trashing
# 0.9944	pathetic
# 0.9943	clintons
# 0.9940	wondered
# 0.9939	angry
# 0.9939	hillary_clinton
# 0.9937	loser
# 0.9937	antics
# 0.9936	bill_clinton
# 0.9936	mainstream_media
#
# tax_cuts
# Pretrained:
# 0.7835	bush_tax
# 0.7509	cutting_taxes
# 0.7235	wealthiest_americans
# 0.7097	cut_taxes
# 0.7044	raising_taxes
# 0.7041	tax_increases
# 0.6913	trillion_tax
# 0.6798	unfunded_tax
# 0.6791	cuts_expire
# 0.6787	cutting_spending
#
# Our model:
# 0.9937	cuts
# 0.9915	tax_increases
# 0.9910	tax_breaks
# 0.9907	cutting_taxes
# 0.9903	raise_taxes
# 0.9902	tax_increase
# 0.9899	raising_taxes
# 0.9896	bush_tax
# 0.9889	budget_cuts
# 0.9888	budget
