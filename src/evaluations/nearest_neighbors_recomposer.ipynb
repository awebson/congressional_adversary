# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/PN/pretrained/init.pt
# /home/webson/Research/congressional_adversary/torch1.5/lib/python3.7/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/webson/Research/congressional_adversary/torch1.5/lib/python3.7/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'decomposer.Decomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Vocab size = 138,443
# ...

# %%
# base_dir = Path('../../results/PN/EWS_recomposer/overcorrect')
base_dir = Path('../../results/PN/GM2')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='*/epoch10.pt', recomposer=True, pretrained=False)

print(deno_space.keys())
# Out:
# ...
# Loading ../../results/PN/GM2/NS5/epoch10.pt
# Loading ../../results/PN/GM2/NS10/epoch10.pt
# Loading ../../results/PN/GM2/BS4096/epoch10.pt
#
# dict_keys(['NS5 epoch10', 'NS10 epoch10', 'BS4096 epoch10'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['NS5 epoch10']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
#     GD(query)
    print(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ...
#              Dataset             Rho       Reference      Delta >.02
# ...
#     EN-MTurk-771.txt         48.79%         49.62%               𝜀
#   EN-RW-STANFORD.txt         41.42%         44.62%          -3.20%
#    EN-SIMLEX-999.txt         29.20%         30.70%               𝜀
#     EN-MTurk-287.txt         54.13%         56.33%          -2.20%
#        EN-YP-130.txt         37.75%         41.14%          -3.39%
#    EN-WS-353-SIM.txt         63.24%         63.87%               𝜀
#     EN-MEN-TR-3k.txt         46.37%         47.35%               𝜀
#    EN-WS-353-REL.txt         38.51%         41.71%          -3.21%
#      EN-VERB-143.txt         29.90%         29.87%               𝜀
#    EN-WS-353-ALL.txt         52.56%         54.88%          -2.32%
#  EN-SimVerb-3500.txt         24.46%         25.62%               𝜀
# Mean Delta = -1.7624%

# %%
GD('aca')

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# estate_tax
# Pretrained:
# 0.8771	death_tax
# 0.8563	richest_americans
# 0.8549	inheritance_tax
# 0.8509	surtax
# 0.8478	alternative_minimum
# 0.8466	top_tax
# 0.8318	high_earners
# 0.8283	trillion_tax
# 0.8262	wealthiest_americans
# 0.8240	increasing_taxes
#
# Our model:
# 0.8300	top_tax
# 0.8252	surtax
# 0.8226	high_earners
# 0.8191	alternative_minimum
# 0.8185	death_tax
# 0.8165	trillion_tax
# 0.8161	marriage_penalty
# 0.8115	increasing_taxes
# 0.8107	franchise_tax
# 0.8094	top_marginal
#
# death_tax
# Pretrained:
# 0.9386	inheritance_tax
# 0.8987	surtax
# 0.8905	wealthy_tax
# 0.8858	repeals_obamacare
# 0.8810	alternative_minimum
# 0.8799	marriage_penalty
# 0.8772	closing_loopholes
# 0.8771	estate_tax
# 0.8754	estate_taxes
# 0.8734	obamacare_taxes
#
# Our model:
# 0.8631	inheritance_tax
# 0.8438	existing_tax
# 0.8421	alternative_minimum
# 0.8406	medicare_benefits
# 0.8349	increasing_taxes
# 0.8346	tax_hike
# 0.8344	energy_tax
# 0.8316	obamacare_taxes
# 0.8249	benefit_programs
# ...

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# undocumented_workers
# Pretrained:
# 0.8351	work_visas
# 0.8273	people_seeking
# 0.8123	legal_immigrants
# 0.8114	hire_illegal
# 0.8063	young_undocumented
# 0.8009	border_crossers
# 0.8003	immigration_agents
# 0.7990	legal_residents
# 0.7986	many_immigrants
# 0.7981	undocumented_people
#
# Our model:
# 0.8458	work_visas
# 0.8229	many_immigrants
# 0.8162	legal_immigrants
# 0.8162	million_unauthorized
# 0.8152	immigration_agents
# 0.8091	people_seeking
# 0.8068	million_immigrants
# 0.8067	convicted_criminals
# 0.8054	hire_illegal
# 0.8039	temporary_work
#
# illegal_aliens
# Pretrained:
# 0.8451	illegals
# 0.8002	illegal_immigrants
# 0.7885	criminal_aliens
# 0.7825	undocumented_immigrants
# 0.7740	illegal_immigrant
# 0.7723	unauthorized_immigrants
# 0.7628	million_illegal
# 0.7517	criminal_illegal
# 0.7504	border_crossers
# 0.7442	deporting
#
# Our model:
# 0.8445	illegals
# 0.7658	illegal_immigrants
# 0.7472	criminal_aliens
# 0.7437	illegal_immigrant
# 0.7273	million_illegal
# ...

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare
# Pretrained:
# 0.8494	aca
# 0.8422	affordable_care
# 0.8105	health_law
# 0.7692	individual_mandate
# 0.7499	republican_plan
# 0.7449	healthcare_law
# 0.7422	care_law
# 0.7415	patient_protection
# 0.7365	ahca
# 0.7361	act_aca
#
# Our model:
# 0.8537	affordable_care
# 0.8231	aca
# 0.7649	individual_mandate
# 0.7600	care_law
# 0.7466	health_insurance
# 0.7334	care_plan
# 0.7333	healthcare_law
# 0.7295	care_reform
# 0.7277	health_law
# 0.7277	replace_obamacare
#
# aca
# Pretrained:
# 0.8494	obamacare
# 0.8348	affordable_care
# 0.8132	health_law
# 0.8107	individual_mandate
# 0.7533	individual_market
# 0.7386	insurance_plans
# 0.7385	patient_protection
# 0.7379	preexisting_conditions
# 0.7357	obamacare_insurance
# 0.7342	health_insurance
#
# Our model:
# 0.8231	obamacare
# 0.8180	affordable_care
# 0.8141	health_law
# 0.8139	individual_mandate
# 0.7636	individual_market
# 0.7526	private_insurance
# 0.7472	marketplaces
# 0.7458	individual_insurance
# 0.7436	insurance_plans
# ...

# %%
# cf('private_account')
# cf('personal_account')
cf('foreign_trade')
cf('international_trade')
cf('drilling')
cf('energy_exploration')
cf('tort_reform')
# cf('lawsuit_abuse_reform')
cf('trial_lawyer')
cf('personal_injury')
# cf('injury_lawyer')
# cf('ambulance_chasers')
# cf('corporate_transparency')
cf('corporate_accountability')
cf('school_choice')
# Out:
# foreign_trade
# Pretrained:
# 0.8142	goods_services
# 0.7943	u.s._products
# 0.7907	open_trade
# 0.7879	trade_investment
# 0.7851	lowering_tariffs
# 0.7826	financial_architecture
# 0.7814	increased_trade
# 0.7753	attracting_foreign
# 0.7741	world_trading
# 0.7729	expanding_trade
#
# Our model:
# 0.7387	goods_services
# 0.7287	trade_investment
# 0.7219	commercial_activities
# 0.7218	based_economy
# 0.7187	economic_engine
# 0.7166	fully_integrated
# 0.7165	outsourcing_jobs
# 0.7131	border_make
# 0.7110	agricultural_interests
# 0.7108	environmental_practices
#
# international_trade
# Pretrained:
# 0.6451	government_deficits
# 0.6242	legal_trade
# 0.6056	trade
# 0.5932	global_trade
# 0.5931	international_environmental
# 0.5825	investment_agreements
# 0.5808	digital_commerce
# 0.5803	trade_expansion
# 0.5786	international_commerce
# 0.5773	existing_trade
#
# Our model:
# 0.5895	legal_trade
# 0.5763	government_deficits
# 0.5295	global_trade
# 0.5266	trade
# 0.5235	existing_trade
# ...

# %%
cf('leftists')
cf('antifa')
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
cf('lgbt')
# Out:
# leftists
# Pretrained:
# 0.7698	fascists
# 0.7664	left_wingers
# 0.7495	called_liberals
# 0.7465	sjws
# 0.7462	hard_left
# 0.7418	marxists
# 0.7388	liberals
# 0.7367	xenophobes
# 0.7362	rightists
# 0.7361	misogynists
#
# Our model:
# 0.6893	hard_left
# 0.6856	marxists
# 0.6835	sjws
# 0.6807	called_liberals
# 0.6700	agitators
# 0.6686	radical_leftists
# 0.6647	left_wingers
# 0.6633	jerks
# 0.6602	feminists
# 0.6600	punks
#
# antifa
# Pretrained:
# 0.8327	anti-fascist
# 0.7933	blacklives_matter
# 0.7690	white_supremacists
# 0.7669	deray_mckesson
# 0.7646	alt_left
# 0.7633	oath_keepers
# 0.7610	neo-nazis
# 0.7603	agitators
# 0.7514	white_nationalists
# 0.7487	matter_protesters
#
# Our model:
# 0.7622	blacklives_matter
# 0.7378	agitators
# 0.7258	anti-cop
# 0.7202	deray_mckesson
# 0.7158	black_bloc
# 0.6944	alt_left
# 0.6919	rioters
# 0.6837	black_clad
# 0.6831	anti-fascist
# 0.6733	black_nationalist
#
# crooked_hillary
# Pretrained:
# 0.8450	lyin_ted
# 0.8403	even_hillary
# ...

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# gun_violence
# Pretrained:
# 0.7665	mass_shootings
# 0.6997	gun_deaths
# 0.6910	school_shootings
# 0.6739	gun_control
# 0.6735	gun-related
# 0.6655	developed_peers
# 0.6653	america_gun
# 0.6652	mass_shooting
# 0.6619	shootings
# 0.6607	gun_laws
#
# Our model:
# 0.7783	mass_shootings
# 0.7339	gun_deaths
# 0.6985	school_shootings
# 0.6927	gun_control
# 0.6889	developed_peers
# 0.6888	gun_laws
# 0.6875	america_gun
# 0.6827	gun-related
# 0.6816	gun_ownership
# 0.6778	mass_shooting
#
# single_payer
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.7675	universal_health
# 0.7448	universal_coverage
# 0.7235	public_option
# 0.7005	universal_healthcare
# 0.6968	government_run
# 0.6669	private_insurance
# 0.6610	care_plan
# 0.6535	comprehensive_health
# ...
