# %%
from pathlib import Path
from typing import Tuple, Union, List, Dict, Iterable, Optional

import torch
import numpy as np
from tqdm.notebook import tqdm

from decomposer import Decomposer, DecomposerConfig
from recomposer import Recomposer, RecomposerConfig
from helpers import *
# Out:
# Loading vocabulary from /home/webson/Research/congressional_adversary/results/PN/pretrained/init.pt
# /home/webson/Research/congressional_adversary/congressional_env/lib/python3.7/site-packages/torch/serialization.py:593: SourceChangeWarning: source code of class 'decomposer.Decomposer' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# Vocab size = 138,443
# /home/webson/Research/congressional_adversary/src/data.py:56: RuntimeWarning: invalid value encountered in long_scalars
#   self.R_ratio = self.cono_freq[2] / (self.cono_freq[0] + self.cono_freq[2])

# %%
base_dir = Path('../../results/PN/EWS_recomposer/overcorrect')
deno_space, cono_space = load_en_masse(
    base_dir, patterns='epoch1.pt', recomposer=True)

print(deno_space.keys())
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# Loading ../../results/PN/EWS_recomposer/overcorrect/epoch1.pt
#
# dict_keys(['pretrained', 'overcorrect epoch1'])

# %%
from evaluations.word_similarity.all_wordsim import mean_delta, read_plain_text, compare
import math

SELECT_MODEL = deno_space['overcorrect epoch1']

def convert(embed):
    word_vecs: Dict[str, np.array] = {}
    for word_id, vector in enumerate(embed):
        vector /= math.sqrt((vector ** 2).sum() + 1e-6)
        word_vecs[ITW[word_id]] = vector
    return word_vecs

def cf_WS(m1, m2):
    compare(convert(m1), convert(m2))

def cf(query):
#     GD(query)
    print(query)
    print('Pretrained:')
    nearest_neighbors(query, PE)
    print('Our model:')
    nearest_neighbors(query, SELECT_MODEL)
    
cf_WS(SELECT_MODEL, PE)
# Out:
# ====================================================================================================
#              Dataset             Rho       Reference      Delta >.02
# ====================================================================================================
#     EN-MTurk-771.txt         49.76%         49.62%               𝜀
#   EN-RW-STANFORD.txt         40.28%         44.62%          -4.35%
#    EN-SIMLEX-999.txt         29.23%         30.70%               𝜀
#     EN-MTurk-287.txt         57.62%         56.33%               𝜀
#        EN-YP-130.txt         45.36%         41.14%           4.22%
#    EN-WS-353-SIM.txt         64.85%         63.87%               𝜀
#     EN-MEN-TR-3k.txt         49.36%         47.34%           2.01%
#    EN-WS-353-REL.txt         44.98%         41.70%           3.27%
#      EN-VERB-143.txt         31.50%         29.87%               𝜀
#    EN-WS-353-ALL.txt         54.17%         54.87%               𝜀
#  EN-SimVerb-3500.txt         24.23%         25.62%               𝜀
# Mean Delta = 0.5118%

# %%
GD('aca')

# %%
cf('estate_tax')
cf('death_tax')
# Out:
# estate_tax
# Pretrained:
# 0.8771	death_tax
# 0.8563	richest_americans
# 0.8549	inheritance_tax
# 0.8509	surtax
# 0.8478	alternative_minimum
# 0.8466	top_tax
# 0.8318	high_earners
# 0.8283	trillion_tax
# 0.8262	wealthiest_americans
# 0.8240	increasing_taxes
#
# Our model:
# 0.7867	alternative_minimum
# 0.7856	death_tax
# 0.7812	top_tax
# 0.7691	high_earners
# 0.7684	trillion_tax
# 0.7644	richest_americans
# 0.7492	increasing_taxes
# 0.7460	wealthiest_americans
# 0.7384	tax_hike
# 0.7357	huge_tax
#
# death_tax
# Pretrained:
# 0.9386	inheritance_tax
# 0.8987	surtax
# 0.8905	wealthy_tax
# 0.8858	repeals_obamacare
# 0.8810	alternative_minimum
# 0.8799	marriage_penalty
# 0.8772	closing_loopholes
# 0.8771	estate_tax
# 0.8754	estate_taxes
# 0.8734	obamacare_taxes
#
# Our model:
# 0.8264	inheritance_tax
# 0.7856	estate_tax
# 0.7798	closing_loopholes
# 0.7713	existing_tax
# 0.7699	alternative_minimum
# 0.7545	surtax
# 0.7522	cuts_expire
# 0.7521	medicare_cuts
# 0.7369	obamacare_taxes
# 0.7341	temporary_tax

# %%
cf('undocumented_workers')
cf('illegal_aliens')
cf('chain_migration')
# Out:
# undocumented_workers
# Pretrained:
# 0.8351	work_visas
# 0.8273	people_seeking
# 0.8123	legal_immigrants
# 0.8114	hire_illegal
# 0.8063	young_undocumented
# 0.8009	border_crossers
# 0.8003	immigration_agents
# 0.7990	legal_residents
# 0.7986	many_immigrants
# 0.7981	undocumented_people
#
# Our model:
# 0.7444	legal_immigrants
# 0.7396	people_seeking
# 0.7335	undocumented_immigrants
# 0.7227	legal_residents
# 0.7176	illegals
# 0.7104	unauthorized_immigrants
# 0.7080	million_undocumented
# 0.7074	illegal_immigrants
# 0.6975	many_immigrants
# 0.6912	u.s._illegally
#
# illegal_aliens
# Pretrained:
# 0.8451	illegals
# 0.8002	illegal_immigrants
# 0.7885	criminal_aliens
# 0.7825	undocumented_immigrants
# 0.7740	illegal_immigrant
# 0.7723	unauthorized_immigrants
# 0.7628	million_illegal
# 0.7517	criminal_illegal
# 0.7504	border_crossers
# 0.7442	deporting
#
# Our model:
# 0.8415	illegals
# 0.7939	illegal_immigrants
# 0.7745	undocumented_immigrants
# 0.7665	illegal_immigrant
# 0.7505	million_illegal
# 0.7496	unauthorized_immigrants
# 0.7401	criminal_aliens
# 0.7385	country_illegally
# 0.7246	legal_immigrants
# 0.7189	million_undocumented
#
# chain_migration
# Pretrained:
# 0.8546	iirira
# 0.8451	called_dreamers
# 0.8387	million_illegals
# 0.8373	executive_amnesty
# 0.8361	immigration_reforms
# 0.8345	young_illegal
# 0.8331	immigration_advocates
# 0.8292	young_undocumented
# 0.8268	undocumented_children
# 0.8255	family_based
#
# Our model:
# 0.7967	family_based
# 0.7306	iirira
# 0.7271	raise_act
# 0.7254	nseers
# 0.6867	hire_illegal
# 0.6829	dapa
# 0.6813	deportation_relief
# 0.6776	expedited_removal
# 0.6756	fly_list
# 0.6743	immigration_proposal

# %%
cf('obamacare')
cf('aca')
cf('public_option')
cf('single_payer')
cf('socialized_medicine')
# Out:
# obamacare
# Pretrained:
# 0.8494	aca
# 0.8422	affordable_care
# 0.8105	health_law
# 0.7692	individual_mandate
# 0.7499	republican_plan
# 0.7449	healthcare_law
# 0.7422	care_law
# 0.7415	patient_protection
# 0.7365	ahca
# 0.7361	act_aca
#
# Our model:
# 0.8478	aca
# 0.8392	affordable_care
# 0.8095	health_law
# 0.7630	individual_mandate
# 0.7431	republican_plan
# 0.7404	care_law
# 0.7328	health_reform
# 0.7311	healthcare_law
# 0.7303	patient_protection
# 0.7299	act_aca
#
# aca
# Pretrained:
# 0.8494	obamacare
# 0.8348	affordable_care
# 0.8132	health_law
# 0.8107	individual_mandate
# 0.7533	individual_market
# 0.7386	insurance_plans
# 0.7385	patient_protection
# 0.7379	preexisting_conditions
# 0.7357	obamacare_insurance
# 0.7342	health_insurance
#
# Our model:
# 0.8478	obamacare
# 0.8314	affordable_care
# 0.8141	health_law
# 0.8082	individual_mandate
# 0.7520	individual_market
# 0.7358	insurance_plans
# 0.7333	health_insurance
# 0.7319	patient_protection
# 0.7266	act_aca
# 0.7263	private_insurance
#
# public_option
# Pretrained:
# 0.7652	medicare_buy
# 0.7636	health_reform
# 0.7521	graham_cassidy
# 0.7472	ahca
# 0.7370	public_plan
# 0.7366	single_payer
# 0.7317	care_reform
# 0.7242	comprehensive_health
# 0.7219	gop_plan
# 0.7215	universal_coverage
#
# Our model:
# 0.7145	health_reform
# 0.7119	single_payer
# 0.6955	graham_cassidy
# 0.6770	care_reform
# 0.6717	universal_coverage
# 0.6717	healthcare_reform
# 0.6654	ahca
# 0.6616	comprehensive_health
# 0.6610	republican_plan
# 0.6543	trumpcare
#
# single_payer
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.7439	universal_health
# 0.7273	universal_coverage
# 0.7119	public_option
# 0.6724	socialized_medicine
# 0.6670	government_run
# 0.6551	free_college
# 0.6446	national_health
# 0.6362	comprehensive_health
# 0.6338	care_plan
# 0.6293	private_insurance
#
# socialized_medicine
# Pretrained:
# 0.8503	government_takeover
# 0.8386	like_obamacare
# 0.8367	socialistic
# 0.8302	end_medicare
# 0.8254	moochers
# 0.8243	universal_healthcare
# 0.8230	healthcare_plan
# 0.8170	freeloaders
# 0.8139	need_health
# 0.8119	hardworking_americans
#
# Our model:
# 0.8161	socialistic
# 0.8032	death_panels
# 0.7864	moochers
# 0.7662	healthcare_plan
# 0.7579	get_government
# 0.7459	conservatives_would
# 0.7369	job_creators
# 0.7364	working_poor
# 0.7318	like_obamacare
# 0.7308	liberal_agenda

# %%
cf('leftists')
cf('antifa')
# Out:
# leftists
# Pretrained:
# 0.7698	fascists
# 0.7664	left_wingers
# 0.7495	called_liberals
# 0.7465	sjws
# 0.7462	hard_left
# 0.7418	marxists
# 0.7388	liberals
# 0.7367	xenophobes
# 0.7362	rightists
# 0.7361	misogynists
#
# Our model:
# 0.7605	fascists
# 0.7413	liberals
# 0.7302	marxists
# 0.7276	hard_left
# 0.7135	bigots
# 0.7082	racists
# 0.7074	political_left
# 0.7052	right_wingers
# 0.6986	socialists
# 0.6956	left_wingers
#
# antifa
# Pretrained:
# 0.8327	anti-fascist
# 0.7933	blacklives_matter
# 0.7690	white_supremacists
# 0.7669	deray_mckesson
# 0.7646	alt_left
# 0.7633	oath_keepers
# 0.7610	neo-nazis
# 0.7603	agitators
# 0.7514	white_nationalists
# 0.7487	matter_protesters
#
# Our model:
# 0.7637	blacklives_matter
# 0.7633	anti-fascist
# 0.7543	white_supremacists
# 0.7367	agitators
# 0.7341	neo-nazis
# 0.7252	white_nationalists
# 0.7217	kkk
# 0.7024	white_supremacist
# 0.6985	alt_right
# 0.6984	black_panthers

# %%
cf('private_account')
cf('personal_account')
# Out:
# private_account
# Pretrained:
# 0.8999	senate_investigators
# 0.8889	personal_server
# 0.8782	email_system
# 0.8729	clinton_server
# 0.8727	personal_account
# 0.8714	email_chain
# 0.8702	tax_documents
# 0.8693	house_staffers
# 0.8656	email_account
# 0.8624	marked_classified
#
# Our model:
# 0.7540	personal_account
# 0.7387	email_account
# 0.7246	clinton_aide
# 0.7117	private_emails
# 0.7000	email_chain
# 0.6888	emails_show
# 0.6886	personal_emails
# 0.6858	campaign_chair
# 0.6829	george_papadopoulos
# 0.6823	emails_sent
#
# personal_account
# Pretrained:
# 0.9065	personal_server
# 0.8818	contained_classified
# 0.8816	marked_classified
# 0.8800	private_emails
# 0.8783	classified_emails
# 0.8770	emails_released
# 0.8765	personal_emails
# 0.8765	emails_sent
# 0.8750	voicemails
# 0.8728	clinton_aide
#
# Our model:
# 0.7868	private_emails
# 0.7572	email_account
# 0.7548	personal_emails
# 0.7540	private_account
# 0.7488	clinton_aide
# 0.7382	clinton_private
# 0.7322	emails_released
# 0.7253	allegedly_sent
# 0.7199	e-mail_messages
# 0.7136	leaked_information

# %%
cf('foreign_trade')
cf('international_trade')
# Out:
# foreign_trade
# Pretrained:
# 0.8142	goods_services
# 0.7943	u.s._products
# 0.7907	open_trade
# 0.7879	trade_investment
# 0.7851	lowering_tariffs
# 0.7826	financial_architecture
# 0.7814	increased_trade
# 0.7753	attracting_foreign
# 0.7741	world_trading
# 0.7729	expanding_trade
#
# Our model:
# 0.7535	open_trade
# 0.7270	strategic_partnerships
# 0.7262	goods_services
# 0.7225	increased_trade
# 0.7151	u.s._goods
# 0.7121	economic_activities
# 0.7055	digital_economy
# 0.7037	economic_gains
# 0.7028	liberalized
# 0.7006	close_partners
#
# international_trade
# Pretrained:
# 0.6451	government_deficits
# 0.6242	legal_trade
# 0.6056	trade
# 0.5932	global_trade
# 0.5931	international_environmental
# 0.5825	investment_agreements
# 0.5808	digital_commerce
# 0.5803	trade_expansion
# 0.5786	international_commerce
# 0.5773	existing_trade
#
# Our model:
# 0.6008	trade
# 0.5829	global_trade
# 0.5757	foreign_trade
# 0.5472	trade_policy
# 0.5403	endangered_species
# 0.5397	agreement_nafta
# 0.5365	trade_barriers
# 0.5356	digital_economy
# 0.5334	u.s._domestic
# 0.5259	sea_unclos

# %%
cf('drilling')
cf('energy_exploration')
# Out:
# drilling
# Pretrained:
# 0.8109	oil_drilling
# 0.7738	gas_drilling
# 0.7571	offshore_drilling
# 0.7439	anwr
# 0.7418	arctic_national
# 0.7312	offshore_oil
# 0.7085	arctic_refuge
# 0.7076	hydraulic_fracturing
# 0.6921	gas_development
# 0.6910	fracking
#
# Our model:
# 0.8015	oil_drilling
# 0.7729	gas_drilling
# 0.7455	offshore_drilling
# 0.7280	offshore_oil
# 0.7202	arctic_national
# 0.6791	shale
# 0.6754	hydraulic_fracturing
# 0.6637	fracking
# 0.6628	gas_exploration
# 0.6512	federal_lands
#
# energy_exploration
# Pretrained:
# 0.9205	new_offshore
# 0.9151	new_drilling
# 0.9112	deepwater_drilling
# 0.9100	gas_exploration
# 0.8952	federal_waters
# 0.8886	private_lands
# 0.8854	management_plans
# 0.8829	kxl
# 0.8809	drilling_sites
# 0.8799	new_fossil
#
# Our model:
# 0.7983	new_offshore
# 0.7829	new_drilling
# 0.7797	federal_waters
# 0.7670	deepwater_drilling
# 0.7589	north_slope
# 0.7204	coastal_plain
# 0.7192	groundwater_pumping
# 0.7162	new_fossil
# 0.7156	tongass
# 0.7148	oil_extraction

# %%
cf('tort_reform')
# cf('lawsuit_abuse_reform')
# Out:
# tort_reform
# Pretrained:
# 0.8110	campaign_reform
# 0.8074	reform_proposal
# 0.8026	trial_lawyers
# 0.7989	reform_advocates
# 0.7983	consumer_groups
# 0.7948	ethics_reforms
# 0.7920	finance_laws
# 0.7910	school_vouchers
# 0.7900	bill_saying
# 0.7895	disclose_act
#
# Our model:
# 0.7467	trial_lawyers
# 0.7386	consumer_groups
# 0.7379	federal_legislation
# 0.7269	insurance_industry
# 0.7225	republican_legislators
# 0.7222	care_reform
# 0.7098	school_vouchers
# 0.7022	business_groups
# 0.6998	reform_law
# 0.6934	education_funding

# %%
cf('trial_lawyer')
cf('personal_injury')
# cf('injury_lawyer')
# cf('ambulance_chasers')
# Out:
# trial_lawyer
# Pretrained:
# 0.8495	criminal_defense
# 0.8442	buzbee
# 0.8280	raley
# 0.8277	paul_green
# 0.8211	tony_buzbee
# 0.8204	state_representative
# 0.8179	longtime_republican
# 0.8153	comer
# 0.8142	hotze
# 0.8100	hecht
#
# Our model:
# 0.8147	criminal_defense
# 0.7970	state_representative
# 0.7758	gina
# 0.7660	state_legislator
# 0.7573	longtime_democratic
# 0.7486	assistant_district
# 0.7429	longtime_republican
# 0.7415	gubernatorial_candidate
# 0.7406	austin_based
# 0.7377	former_aide
#
# personal_injury
# Pretrained:
# 0.8911	civil_suits
# 0.8836	wrongful_death
# 0.8808	fraud_case
# 0.8776	successfully_argued
# 0.8667	attorney_fees
# 0.8611	civil_suit
# 0.8569	texas_civil
# 0.8566	case_involves
# 0.8551	attorneys_said
# 0.8549	private_attorney
#
# Our model:
# 0.7663	wrongful_death
# 0.7630	fraud_case
# 0.7497	civil_suit
# 0.7427	attorney_fees
# 0.7309	successfully_argued
# 0.7289	civil_case
# 0.7178	attorney_representing
# 0.7121	municipal_court
# 0.7111	lawsuit_said
# 0.7111	fraud_charges

# %%
# cf('corporate_transparency')
cf('corporate_accountability')
# Out:
# corporate_accountability
# Pretrained:
# 0.8881	photo_istockphoto
# 0.8860	putting_additional
# 0.8848	robert_kepple
# 0.8815	support_nonprofit
# 0.8808	laura_huffman
# 0.8765	nation_underperforming
# 0.8765	nb_staff
# 0.8760	john_esparza
# 0.8760	powerful_grassroots
# 0.8724	larry_soward
#
# Our model:
# 0.5976	rainforest_action
# 0.5895	interest_research
# 0.5870	based_nonprofit
# 0.5829	texas_chapter
# 0.5753	d.c._based
# 0.5753	american_lung
# 0.5744	consumer_advocacy
# 0.5686	national_education
# 0.5638	consumer_rights
# 0.5546	research_association

# %%
cf('school_choice')
# Out:
# school_choice
# Pretrained:
# 0.8459	school_vouchers
# 0.7874	pre_k
# 0.7657	charter_schools
# 0.7536	early_education
# 0.7499	school_voucher
# 0.7450	education_policy
# 0.7446	private_school
# 0.7440	pre-kindergarten
# 0.7408	parent_trigger
# 0.7376	standardized_testing
#
# Our model:
# 0.8086	school_vouchers
# 0.7449	pre_k
# 0.7397	charter_schools
# 0.7139	private_school
# 0.7055	education_policy
# 0.6990	vouchers
# 0.6935	standardized_testing
# 0.6901	local_control
# 0.6851	charter_school
# 0.6597	tort_reform

# %%
cf('crooked_hillary')
cf('lyin_ted')
cf('little_marco')
# Out:
# crooked_hillary
# Pretrained:
# 0.8450	lyin_ted
# 0.8403	even_hillary
# 0.8385	little_marco
# 0.8378	el_trumpo
# 0.8374	attack_hillary
# 0.8372	vast_right
# 0.8359	wing_conspiracy
# 0.8349	calling_trump
# 0.8338	con_artist
# 0.8327	lyin
#
# Our model:
# 0.8304	el_trumpo
# 0.8275	vast_right
# 0.8243	wing_conspiracy
# 0.8205	calling_trump
# 0.8081	con_artist
# 0.8061	sycophant
# 0.8053	like_hillary
# 0.8015	reince
# 0.8004	cheap_shot
# 0.7992	con_man
#
# lyin_ted
# Pretrained:
# 0.9466	little_marco
# 0.9024	lyin
# 0.8855	real_donald
# 0.8736	trump_calling
# 0.8733	typical_politician
# 0.8728	paladino
# 0.8698	really_likes
# 0.8696	small_hands
# 0.8695	called_romney
# 0.8688	palin_says
#
# Our model:
# 0.7109	called_romney
# 0.7010	really_likes
# 0.7007	endorse_donald
# 0.6962	business_mogul
# 0.6852	yuge
# 0.6852	presidential_wannabe
# 0.6814	big_mouth
# 0.6809	palin_says
# 0.6770	hilary_rosen
# 0.6761	pissy
#
# little_marco
# Pretrained:
# 0.9466	lyin_ted
# 0.9232	lyin
# 0.9134	even_donald
# 0.9115	real_donald
# 0.9049	ted_cruz.
# 0.9037	typical_politician
# 0.9032	called_romney
# 0.9019	trump_calling
# 0.8983	hitting_back
# 0.8941	romney_supporter
#
# Our model:
# 0.8422	real_donald
# 0.8349	skidmore_flickr
# 0.8280	bad_night
# 0.8244	o.k
# 0.8194	vp_debate
# 0.8156	open_marriage
# 0.8114	gotcha_question
# 0.8075	stupid_party
# 0.8074	cruz_continued
# 0.8065	hillary_lost

# %%
cf('lgbt')
# Out:
# Pretrained:
# 0.7943	gay_lesbian
# 0.7506	lgbt_community
# 0.7398	transgender
# 0.7358	bisexual
# 0.7317	glaad
# 0.7188	transgender_community
# 0.7158	transgender_rights
# 0.7138	lesbian_gay
# 0.7016	lgbt_movement
# 0.6988	lgbtq_community
#
# Our model:
# 0.7879	gay_lesbian
# 0.7605	transgender
# 0.7462	bisexual
# 0.7282	transgender_rights
# 0.7188	glaad
# 0.7170	transgender_community
# 0.7089	lesbian_gay
# 0.7065	transgendered
# 0.7035	queer
# 0.7012	lgbt_movement

# %%
# 5-bin high PMI
cf('gun_violence')
cf('single_payer')
cf('medicaid_expansion')
cf('birth_control')
cf('tax_returns')

cf('global_warming')
cf('climate_change')
cf('clean_energy')

cf('undocumented_immigrants')
cf('counterterrorism_wars')
cf('us_debt')
cf('monetary_policy')
cf('financial_markets')

cf('violence_racism')
cf('permanently_banned')
cf('anti-semitism')
cf('neocons')
cf('veterans')
cf('professors')
cf('jihadists')
cf('irs')
cf('social_justice')
cf('political_correctness')
cf('mainstream_media')
cf('hillary')

# 3-bin high PMI
cf('tax_cuts')
# Out:
# gun_violence
# Pretrained:
# 0.7665	mass_shootings
# 0.6997	gun_deaths
# 0.6910	school_shootings
# 0.6739	gun_control
# 0.6735	gun-related
# 0.6655	developed_peers
# 0.6653	america_gun
# 0.6652	mass_shooting
# 0.6619	shootings
# 0.6607	gun_laws
#
# Our model:
# 0.7635	mass_shootings
# 0.6907	gun_deaths
# 0.6730	gun_control
# 0.6728	school_shootings
# 0.6686	gun-related
# 0.6616	mass_shooting
# 0.6587	shootings
# 0.6564	gun_laws
# 0.6499	gun_ownership
# 0.6407	gun_safety
#
# single_payer
# Pretrained:
# 0.7524	universal_health
# 0.7498	universal_coverage
# 0.7366	public_option
# 0.7360	universal_healthcare
# 0.7093	free_college
# 0.6930	socialized_medicine
# 0.6901	comprehensive_health
# 0.6826	government_run
# 0.6647	care_plan
# 0.6554	national_health
#
# Our model:
# 0.7395	universal_health
# 0.7200	public_option
# 0.7168	universal_coverage
# 0.6982	universal_healthcare
# 0.6901	free_college
# 0.6703	socialized_medicine
# 0.6703	government_run
# 0.6561	comprehensive_health
# 0.6415	care_plan
# 0.6319	national_health
#
# medicaid_expansion
# Pretrained:
# 0.8240	obamacare_medicaid
# 0.8239	expanding_medicaid
# 0.8146	expand_medicaid
# 0.8130	expanded_medicaid
# 0.8066	medicaid_program
# 0.7914	medicaid
# 0.7896	health_law
# 0.7493	federal_health
# 0.7473	block_grant
# 0.7464	kynect
#
# Our model:
# 0.8173	expanding_medicaid
# 0.8148	expand_medicaid
# 0.8040	medicaid_program
# 0.8017	expanded_medicaid
# 0.7936	obamacare_medicaid
# 0.7891	medicaid
# 0.7554	health_law
# 0.7433	block_grant
# 0.7325	federal_health
# 0.7324	ahca
#
# birth_control
# Pretrained:
# 0.8883	contraception
# 0.8489	contraceptives
# 0.7916	contraceptive
# 0.7277	iuds
# 0.7141	emergency_contraception
# 0.6993	pills
# 0.6951	abortions
# 0.6934	women_use
# 0.6933	abortion
# 0.6911	long_acting
#
# Our model:
# 0.8890	contraception
# 0.8483	contraceptives
# 0.7839	contraceptive
# 0.6953	pills
# 0.6938	abortion
# 0.6909	abortions
# 0.6865	pill
# 0.6795	reproductive_health
# 0.6793	insurance_coverage
# 0.6764	cancer_screenings
#
# tax_returns
# Pretrained:
# 0.6884	romney_wo
# 0.6819	tax_records
# 0.6807	college_records
# 0.6563	romney_tax
# 0.6504	financial_disclosures
# 0.6503	tax_documents
# 0.6467	multiple_years
# 0.6263	obama_birth
# 0.6255	trump_tax
# 0.6195	medical_records
#
# Our model:
# 0.6257	financial_disclosures
# 0.6210	romney_tax
# 0.6031	obama_birth
# 0.5953	medical_records
# 0.5945	trump_tax
# 0.5897	birth_certificate
# 0.5867	trump_claims
# 0.5864	romneys
# 0.5831	financial_disclosure
# 0.5801	romney_says
#
# global_warming
# Pretrained:
# 0.8320	climate_change
# 0.7507	human_caused
# 0.7387	warming
# 0.7234	human_activity
# 0.7107	climate_scientists
# 0.6952	anthropogenic_global
# 0.6939	alarmists
# 0.6911	climate_crisis
# 0.6906	skeptic_guide
# 0.6899	scientific_consensus
#
# Our model:
# 0.8308	climate_change
# 0.7399	warming
# 0.7289	human_caused
# 0.7266	human_activity
# 0.7071	climate_scientists
# 0.7030	anthropogenic_global
# 0.6887	global_climate
# 0.6866	scientific_consensus
# 0.6717	deniers
# 0.6685	human_induced
#
# climate_change
# Pretrained:
# 0.8320	global_warming
# 0.7031	global_climate
# 0.6997	human_caused
# 0.6588	climate_crisis
# 0.6565	human_activity
# 0.6541	intergovernmental_panel
# 0.6434	climate_science
# 0.6378	world_climate
# 0.6303	skeptic_guide
# 0.6290	scientific_consensus
#
# Our model:
# 0.8308	global_warming
# 0.6973	global_climate
# 0.6756	human_caused
# 0.6536	human_activity
# 0.6477	intergovernmental_panel
# 0.6389	climate_science
# 0.6221	climate
# 0.6189	scientific_consensus
# 0.6174	warming
# 0.6148	anthropogenic_global
#
# clean_energy
# Pretrained:
# 0.6950	low_carbon
# 0.6939	renewable_energy
# 0.6902	renewables
# 0.6819	green_energy
# 0.6705	energy_efficiency
# 0.6662	clean_coal
# 0.6660	solar_energy
# 0.6479	new_energy
# 0.6444	alternative_energy
# 0.6368	solar_power
#
# Our model:
# 0.7020	low_carbon
# 0.6957	renewable_energy
# 0.6947	renewables
# 0.6901	green_energy
# 0.6776	energy_efficiency
# 0.6738	clean_coal
# 0.6691	solar_energy
# 0.6531	new_energy
# 0.6485	alternative_energy
# 0.6400	solar_power
#
# undocumented_immigrants
# Pretrained:
# 0.8427	illegal_immigrants
# 0.8257	unauthorized_immigrants
# 0.8221	million_undocumented
# 0.7906	young_undocumented
# 0.7825	illegal_aliens
# 0.7817	undocumented_workers
# 0.7799	illegals
# 0.7788	country_illegally
# 0.7701	million_illegal
# 0.7692	criminal_aliens
#
# Our model:
# 0.8450	illegal_immigrants
# 0.8267	million_undocumented
# 0.8246	unauthorized_immigrants
# 0.7842	illegal_aliens
# 0.7811	illegals
# 0.7789	country_illegally
# 0.7741	million_illegal
# 0.7738	undocumented_workers
# 0.7604	million_immigrants
# 0.7593	undocumented
#
# counterterrorism_wars
# Pretrained:
# 0.9597	conflict_heads
# 0.9499	africa_nigeria
# 0.9446	counterterrorism_nigeria
# 0.9413	africa_terrorism
# 0.9376	conflict_niger
# 0.9332	counterterrorism_heads
# 0.9280	counterterrorism_corruption
# 0.9271	religion_terrorism
# 0.9221	voting_terrorism
# 0.9214	nigeria_terrorism
#
# Our model:
# 0.9592	conflict_heads
# 0.9497	africa_nigeria
# 0.9440	counterterrorism_nigeria
# 0.9396	africa_terrorism
# 0.9352	conflict_niger
# 0.9268	counterterrorism_heads
# 0.9193	nigeria_terrorism
# 0.9193	counterterrorism_corruption
# 0.9170	religion_terrorism
# 0.9166	voting_terrorism
#
# us_debt
# Pretrained:
# 0.8624	agency_bonds
# 0.8601	us_equities
# 0.8555	us_treasuries
# 0.8498	foreign_purchases
# 0.8470	us_long
# 0.8449	us_securities
# 0.8424	us_bonds
# 0.8420	private_purchases
# 0.8395	term_assets
# 0.8380	agency_debt
#
# Our model:
# 0.8585	agency_bonds
# 0.8580	us_equities
# 0.8553	us_treasuries
# 0.8436	foreign_purchases
# 0.8426	us_long
# 0.8379	private_purchases
# 0.8342	us_bonds
# 0.8320	treasury_bonds
# 0.8293	chinese_purchases
# 0.8270	china_purchases
#
# monetary_policy
# Pretrained:
# 0.6796	zero_bound
# 0.6512	taylor_rule
# 0.6260	fiscal_policy
# 0.6134	financial_markets
# 0.6079	budget_debt
# 0.6070	states_monetary
# 0.6059	markets_united
# 0.6057	states_budget
# 0.6052	japan_boj
# 0.6048	bank_ecb
#
# Our model:
# 0.6293	fiscal_policy
# 0.6164	deficits_trade
# 0.6161	financial_markets
# 0.6132	states_budget
# 0.6072	budget_debt
# 0.6035	forward_guidance
# 0.6024	currency_reserves
# 0.6004	bank_ecb
# 0.5957	china_monetary
# 0.5955	european_central
#
# financial_markets
# Pretrained:
# 0.6455	china_economics
# 0.6374	markets_united
# 0.6352	deficits_economic
# 0.6352	states_budget
# 0.6346	economic_crises
# 0.6302	eurasia_financial
# 0.6285	states_monetary
# 0.6268	japan_boj
# 0.6257	policy_brazil
# 0.6231	development_monetary
#
# Our model:
# 0.6330	china_economics
# 0.6229	economic_crises
# 0.6217	states_budget
# 0.6161	monetary_policy
# 0.6064	organizations_economic
# 0.6002	crises_economics
# 0.5920	deficits_international
# 0.5910	capital_flows
# 0.5857	currency_reserves
# 0.5834	policy_financial
#
# violence_racism
# Pretrained:
# 0.9341	vulgarity_profanity
# 0.9205	comments_containing
# 0.9147	advertising_vulgarity
# 0.9058	contain_spam
# 0.8967	discourteous_behavior
# 0.8910	remove_comments
# 0.7545	au_leaders
# 0.7282	remedies_available
# 0.7149	edit
# 0.7066	african_officials
#
# Our model:
# 0.9306	vulgarity_profanity
# 0.9176	comments_containing
# 0.9153	advertising_vulgarity
# 0.9066	contain_spam
# 0.8941	discourteous_behavior
# 0.8910	remove_comments
# 0.7171	edit
# 0.7016	african_officials
# 0.6424	misappropriation
# 0.6285	anti-semitism
#
# permanently_banned
# Pretrained:
# 0.9781	site_administrators
# 0.9747	repeat_offenders
# 0.9680	sole_discretion
# 0.9107	without_warning
# 0.7716	week_technology
# 0.7672	quick_round
# 0.6748	east_strategic
# 0.6533	well_make
# 0.6499	fact_vietnam
# 0.6497	members_may
#
# Our model:
# 0.9794	site_administrators
# 0.9750	repeat_offenders
# 0.9691	sole_discretion
# 0.9125	without_warning
# 0.7684	week_technology
# 0.7621	quick_round
# 0.6461	members_may
# 0.6290	tribune_donors
# 0.6258	web_version
# 0.6187	gotnews_mission
#
# anti-semitism
# Pretrained:
# 0.7256	anti-zionism
# 0.6891	anti-israelism
# 0.6737	islamophobia
# 0.6670	au_leaders
# 0.6666	anti-jewish
# 0.6499	holocaust_denial
# 0.6415	central_feature
# 0.6412	advertising_vulgarity
# 0.6356	bigotry
# 0.6336	anti-semite
#
# Our model:
# 0.6720	islamophobia
# 0.6622	anti-jewish
# 0.6456	advertising_vulgarity
# 0.6447	holocaust_denial
# 0.6349	bigotry
# 0.6297	anti-semite
# 0.6285	violence_racism
# 0.6261	contain_spam
# 0.6179	african_officials
# 0.6171	white_nationalism
#
# neocons
# Pretrained:
# 0.8623	neoconservatives
# 0.8094	liberal_interventionists
# 0.7870	warmongers
# 0.7836	neoconservative
# 0.7771	liberal_interventionist
# 0.7691	official_washington
# 0.7532	war_hawks
# 0.7481	neo-conservative
# 0.7297	israeli_lobby
# 0.7290	war_party
#
# Our model:
# 0.8599	neoconservatives
# 0.7843	warmongers
# 0.7777	neoconservative
# 0.7447	official_washington
# 0.7232	neo-conservative
# 0.7120	pro-war
# 0.7119	interventionists
# 0.7093	zionist_lobby
# 0.7059	israeli_lobby
# 0.7032	warmongering
#
# veterans
# Pretrained:
# 0.8004	vets
# 0.7329	combat_veterans
# 0.7319	military_families
# 0.7112	helping_veterans
# 0.7109	vietnam_veterans
# 0.7084	disabled_veterans
# 0.7080	many_veterans
# 0.7076	va
# 0.7042	veterans_affairs
# 0.7031	disabled_american
#
# Our model:
# 0.7960	vets
# 0.7240	military_families
# 0.7102	many_veterans
# 0.7055	va
# 0.7018	veterans_affairs
# 0.7004	disabled_veterans
# 0.6998	vietnam_veterans
# 0.6780	military_veterans
# 0.6731	servicemembers
# 0.6673	fellow_veterans
#
# professors
# Pretrained:
# 0.7521	faculty_members
# 0.7434	faculty
# 0.7240	students
# 0.7104	university_professors
# 0.6980	administrators
# 0.6933	undergraduates
# 0.6795	profs
# 0.6787	college_professors
# 0.6776	law_schools
# 0.6763	graduate_students
#
# Our model:
# 0.7469	faculty_members
# 0.7451	faculty
# 0.7239	students
# 0.6972	administrators
# 0.6898	undergraduates
# 0.6773	university_presidents
# 0.6755	graduate_students
# 0.6638	college_professors
# 0.6612	faculty_member
# 0.6531	tenured
#
# jihadists
# Pretrained:
# 0.7782	islamic_extremists
# 0.7565	jihadi
# 0.7557	jihadi_groups
# 0.7525	foreign_fighters
# 0.7505	takfiri
# 0.7485	sunni_extremists
# 0.7473	terror_groups
# 0.7407	isis_al
# 0.7404	islamic_terrorists
# 0.7385	global_jihad
#
# Our model:
# 0.7666	islamic_extremists
# 0.7576	jihadi
# 0.7569	jihadi_groups
# 0.7516	terror_groups
# 0.7504	foreign_fighters
# 0.7474	takfiri
# 0.7412	islamic_terrorists
# 0.7251	terror_group
# 0.7250	nusra_front
# 0.7230	isis_al
#
# irs
# Pretrained:
# 0.7698	internal_revenue
# 0.7172	lois_lerner
# 0.6720	tax_exempt
# 0.6684	i.r.s.
# 0.6535	irs_official
# 0.6484	irs_targeting
# 0.6434	obama_irs
# 0.6395	conservative_groups
# 0.6391	extra_scrutiny
# 0.6328	irs_agents
#
# Our model:
# 0.7584	internal_revenue
# 0.6993	lois_lerner
# 0.6702	tax_exempt
# 0.6267	conservative_groups
# 0.6190	irs_targeting
# 0.5934	lerner
# 0.5802	fec
# 0.5727	audited
# 0.5713	congressional_investigators
# 0.5596	judicial_watch
#
# social_justice
# Pretrained:
# 0.7290	economic_justice
# 0.6677	intersectional
# 0.6552	anti-racism
# 0.6545	intersectionality
# 0.6451	intellectual_diversity
# 0.6371	women_movement
# 0.6286	activists_like
# 0.6269	social_activism
# 0.6250	white_identity
# 0.6249	men_rights
#
# Our model:
# 0.7290	economic_justice
# 0.6620	intersectional
# 0.6487	intersectionality
# 0.6402	anti-racism
# 0.6323	queer
# 0.6269	anti-racist
# 0.6133	anti-capitalist
# 0.6125	safe_spaces
# 0.6117	racial_equality
# 0.6100	environmental_justice
#
# political_correctness
# Pretrained:
# 0.7275	politically_correct
# 0.7091	cultural_marxism
# 0.7089	incivility
# 0.7054	agitprop
# 0.7032	correctness
# 0.7027	toxic_masculinity
# 0.7023	yale_porn
# 0.6973	anti-muslim_bigotry
# 0.6967	sjws
# 0.6961	cultural_marxist
#
# Our model:
# 0.7270	politically_correct
# 0.7056	correctness
# 0.6993	safe_spaces
# 0.6950	conservative_students
# 0.6931	identity_politics
# 0.6897	called_racist
# 0.6866	opposing_views
# 0.6840	immorality
# 0.6799	vulgarity
# 0.6756	incivility
#
# mainstream_media
# Pretrained:
# 0.7718	msm
# 0.7553	mainstream_press
# 0.7465	liberal_media
# 0.7374	corporate_media
# 0.7331	news_media
# 0.7268	main_stream
# 0.7254	establishment_media
# 0.7200	mainstream_news
# 0.7162	called_mainstream
# 0.7153	us_media
#
# Our model:
# 0.7718	msm
# 0.7543	mainstream_press
# 0.7405	liberal_media
# 0.7382	corporate_media
# 0.7358	news_media
# 0.7217	main_stream
# 0.7207	establishment_media
# 0.7138	mainstream_news
# 0.6967	us_media
# 0.6857	alternative_media
#
# hillary
# Pretrained:
# 0.8370	hillary_clinton
# 0.8195	clinton
# 0.6946	clintons
# 0.6939	like_hillary
# 0.6840	clinton_campaign
# 0.6835	crooked_hillary
# 0.6699	mrs._clinton
# 0.6656	bernie
# 0.6567	see_hillary
# 0.6567	think_hillary
#
# Our model:
# 0.8358	hillary_clinton
# 0.8193	clinton
# 0.6946	clintons
# 0.6871	like_hillary
# 0.6845	clinton_campaign
# 0.6838	crooked_hillary
# 0.6654	bernie
# 0.6639	mrs._clinton
# 0.6557	whether_hillary
# 0.6509	obama_clinton
#
# tax_cuts
# Pretrained:
# 0.7835	bush_tax
# 0.7509	cutting_taxes
# 0.7235	wealthiest_americans
# 0.7097	cut_taxes
# 0.7044	raising_taxes
# 0.7041	tax_increases
# 0.6913	trillion_tax
# 0.6798	unfunded_tax
# 0.6791	cuts_expire
# 0.6787	cutting_spending
#
# Our model:
# 0.7815	bush_tax
# 0.7500	cutting_taxes
# 0.7247	wealthiest_americans
# 0.7083	cut_taxes
# 0.7060	raising_taxes
# 0.7028	tax_increases
# 0.6885	trillion_tax
# 0.6798	raises_taxes
# 0.6757	tax_hike
# 0.6750	cutting_spending
